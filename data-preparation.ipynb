# %% [markdown]
# # Data Preparation of the Substitute Recommender Model

# %% [markdown]
# This notebook documents the preparation of the relevant data for the implementation of the Substitute Recommender Model (SRM).
#
# In chapter 1.0, the dataset for training the word2vec model is described and prepared.
# In chapter 2.0, the ingredient list needed for filtering the results is described and prepared.

# %% [markdown]
# - install all required libraries

# %%
pip install gensim
# Out:
# Requirement already satisfied: gensim in /Users/laurapwieler/opt/anaconda3/lib/python3.8/site-packages (4.1.2)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/laurapwieler/opt/anaconda3/lib/python3.8/site-packages (from gensim) (5.2.0)
# Requirement already satisfied: numpy>=1.17.0 in /Users/laurapwieler/opt/anaconda3/lib/python3.8/site-packages (from gensim) (1.22.0)
# Requirement already satisfied: scipy>=0.18.1 in /Users/laurapwieler/opt/anaconda3/lib/python3.8/site-packages (from gensim) (1.7.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install flashtext
# Out:
# Requirement already satisfied: flashtext in /Users/laurapwieler/opt/anaconda3/lib/python3.8/site-packages (2.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
import gensim
import gensim.parsing.preprocessing as pp
from gensim.parsing.preprocessing import STOPWORDS
from gensim import utils
from gensim.models.phrases import Phrases

import pandas as pd
import numpy as np

import re

from flashtext import KeywordProcessor

# %% [markdown]
# ## 1.0 Training Data

# %% [markdown]
# The final training dataset consists of the following five individual recipe datasets:
#
#     (1) RecipeNLG_dataset.csv, sourced from Kaggle
#     (2) recipes.csv, sourced from Kaggle
#     (3) recipes_raw_nosource_ar.json, sourced from GitHub
#     (4) recipes_raw_nosource_epi.json, sourced from GitHub
#     (5) recipes_raw_nosource_fn.json, sourced from GitHub

# %% [markdown]
# ### 1.1 Building the Training Dataset
# #### 1.1.1 Individual Datasets
#
# In the following the individual training datasets are examined and prepared for further use.

# %% [markdown]
# ##### RecipeNLG Dataset
#
# - read (1) RecipeNLG_dataset.csv as DataFrame

# %%
data_RecipeNLG = pd.read_csv("RecipeNLG_dataset.csv")

# %%
data_RecipeNLG.head()
# Out:
#    Unnamed: 0                  title  \
# 0           0    No-Bake Nut Cookies
# 1           1  Jewell Ball'S Chicken
# 2           2            Creamy Corn
# 3           3          Chicken Funny
# 4           4   Reeses Cups(Candy)
#
#                                          ingredients  \
# 0  ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 1  ["1 small jar chipped beef, cut up", "4 boned ...
# 2  ["2 (16 oz.) pkg. frozen corn", "1 (8 oz.) pkg...
# 3  ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# 4  ["1 c. peanut butter", "3/4 c. graham cracker ...
#
#                                           directions  \
# 0  ["In a heavy 2-quart saucepan, mix brown sugar...
# 1  ["Place chipped beef on bottom of baking dish....
# 2  ["In a slow cooker, combine all ingredients. C...
# 3  ["Boil and debone chicken.", "Put bite size pi...
# 4  ["Combine first four ingredients and press in ...
#
#                                               link    source  \
# 0   www.cookbooks.com/Recipe-Details.aspx?id=44874  Gathered
# 1  www.cookbooks.com/Recipe-Details.aspx?id=699419  Gathered
# 2   www.cookbooks.com/Recipe-Details.aspx?id=10570  Gathered
# 3  www.cookbooks.com/Recipe-Details.aspx?id=897570  Gathered
# 4  www.cookbooks.com/Recipe-Details.aspx?id=659239  Gathered
#
#                                                  NER
# 0  ["brown sugar", "milk", "vanilla", "nuts", "bu...
# 1  ["beef", "chicken breasts", "cream of mushroom...
# 2  ["frozen corn", "cream cheese", "butter", "gar...
# 3  ["chicken", "chicken gravy", "cream of mushroo...
# 4  ["peanut butter", "graham cracker crumbs", "bu...

# %% [markdown]
# - rename the relevant column for the training dataset and drop irrelevant columns

# %%
data_RecipeNLG.rename(columns={'directions':'instructions'}, inplace=True)

# %%
data_RecipeNLG_instructions = data_RecipeNLG.drop(['title', 'link', 'source', 'NER', 'ingredients', 'Unnamed: 0'], axis=1)
data_RecipeNLG_instructions.head()
# Out:
#                                         instructions
# 0  ["In a heavy 2-quart saucepan, mix brown sugar...
# 1  ["Place chipped beef on bottom of baking dish....
# 2  ["In a slow cooker, combine all ingredients. C...
# 3  ["Boil and debone chicken.", "Put bite size pi...
# 4  ["Combine first four ingredients and press in ...

# %% [markdown]
# Examine the RecipeNLG dataset:

# %%
data_RecipeNLG_instructions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2231142 entries, 0 to 2231141
# Data columns (total 1 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   instructions  object
# dtypes: object(1)
# memory usage: 17.0+ MB

# %% [markdown]
# - check for missing values

# %%
data_RecipeNLG_instructions.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# - check  length of dataset, i.e., the amount of recipes presented in the dataset

# %%
len(data_RecipeNLG_instructions)
# Out:
# 2231142

# %% [markdown]
# ##### recipes Dataset
#
# - read (2) recipes.csv as DataFrame

# %%
data_recipes = pd.read_csv("recipes.csv")

# %%
data_recipes.head()
# Out:
#    RecipeId                               Name  AuthorId      AuthorName  \
# 0        38  Low-Fat Berry Blue Frozen Dessert      1533          Dancer
# 1        39                            Biryani      1567        elly9812
# 2        40                      Best Lemonade      1566  Stephen Little
# 3        41     Carina's Tofu-Vegetable Kebabs      1586         Cyclopz
# 4        42                       Cabbage Soup      1538       Duckie067
#
#   CookTime PrepTime TotalTime         DatePublished  \
# 0    PT24H    PT45M  PT24H45M  1999-08-09T21:46:00Z
# 1    PT25M     PT4H   PT4H25M  1999-08-29T13:12:00Z
# 2     PT5M    PT30M     PT35M  1999-09-05T19:52:00Z
# 3    PT20M    PT24H  PT24H20M  1999-09-03T14:54:00Z
# 4    PT30M    PT20M     PT50M  1999-09-19T06:19:00Z
#
#                                          Description  \
# 0  Make and share this Low-Fat Berry Blue Frozen ...
# 1  Make and share this Biryani recipe from Food.com.
# 2  This is from one of my  first Good House Keepi...
# 3  This dish is best prepared a day in advance to...
# 4  Make and share this Cabbage Soup recipe from F...
#
#                                               Images  ... SaturatedFatContent  \
# 0  c("https://img.sndimg.com/food/image/upload/w_...  ...                 1.3
# 1  c("https://img.sndimg.com/food/image/upload/w_...  ...                16.6
# 2  c("https://img.sndimg.com/food/image/upload/w_...  ...                 0.0
# 3  c("https://img.sndimg.com/food/image/upload/w_...  ...                 3.8
# 4  "https://img.sndimg.com/food/image/upload/w_55...  ...                 0.1
#
#   CholesterolContent SodiumContent CarbohydrateContent  FiberContent  \
# 0                8.0          29.8                37.1           3.6
# 1              372.8         368.4                84.4           9.0
# 2                0.0           1.8                81.5           0.4
# 3                0.0        1558.6                64.2          17.3
# 4                0.0         959.3                25.1           4.8
#
#    SugarContent  ProteinContent  RecipeServings  RecipeYield  \
# 0          30.2             3.2             4.0          NaN
# 1          20.4            63.4             6.0          NaN
# 2          77.2             0.3             4.0          NaN
# 3          32.1            29.3             2.0     4 kebabs
# 4          17.7             4.3             4.0          NaN
#
#                                   RecipeInstructions
# 0  c("Toss 2 cups berries with sugar.", "Let stan...
# 1  c("Soak saffron in warm milk for 5 minutes and...
# 2  c("Into a 1 quart Jar with tight fitting lid, ...
# 3  c("Drain the tofu, carefully squeezing out exc...
# 4  c("Mix everything together and bring to a boil...
#
# [5 rows x 28 columns]

# %% [markdown]
# - rename the relevant column for the training dataset and drop irrelevant columns

# %%
data_recipes.rename(columns={'RecipeInstructions':'instructions'}, inplace=True)

# %%
data_recipes_instructions = data_recipes.drop(['Name', 'RecipeId', 'AuthorId', 'AuthorName', 'CookTime', 'PrepTime', 'TotalTime', 'DatePublished', 'Description', 'Images', 'RecipeIngredientParts', 'RecipeCategory', 'Keywords', 'RecipeIngredientQuantities', 'AggregatedRating', 'ReviewCount', 'Calories', 'FatContent', 'SaturatedFatContent', 'CholesterolContent', 'SodiumContent', 'CarbohydrateContent', 'FiberContent', 'SugarContent', 'ProteinContent', 'RecipeServings', 'RecipeYield'], axis=1)
data_recipes_instructions.head()
# Out:
#                                         instructions
# 0  c("Toss 2 cups berries with sugar.", "Let stan...
# 1  c("Soak saffron in warm milk for 5 minutes and...
# 2  c("Into a 1 quart Jar with tight fitting lid, ...
# 3  c("Drain the tofu, carefully squeezing out exc...
# 4  c("Mix everything together and bring to a boil...

# %% [markdown]
# Examine the recipes dataset:

# %%
data_recipes_instructions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522517 entries, 0 to 522516
# Data columns (total 1 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   instructions  522517 non-null  object
# dtypes: object(1)
# memory usage: 4.0+ MB

# %% [markdown]
# - check for missing values

# %%
data_recipes_instructions.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# - check length of dataset, i.e., the amount of recipes presented in the dataset

# %%
len(data_recipes_instructions)
# Out:
# 522517

# %% [markdown]
# ##### recipes_raw_nosource_{recipe_sources}.json Datasets
#
# As these three datasets are identical in their structure, they are combined first before proceeded further.
#
# - read (3) recipes_raw_nosource_ar as DataFrames

# %%
data_recipes_raw_nosource_ar = pd.read_json('recipes_raw_nosource_ar.json')

# %%
data_recipes_raw_nosource_ar = data_recipes_raw_nosource_ar.transpose()
data_recipes_raw_nosource_ar.head()
# Out:
#                                                              title  \
# rmK12Uau.ntP510KeImX506H6Mr6jTu  Slow Cooker Chicken and Dumplings
# 5ZpZE8hSVdPk2ZXo1mZTyoPWJRSCPSm      Awesome Slow Cooker Pot Roast
# clyYQv.CplpwJtjNaFGhx0VilNYqRxu               Brown Sugar Meatloaf
# BmqFAmCrDHiKNwX.IQzb0U/v0mLlxFu        Best Chocolate Chip Cookies
# N.jCksRjB4MFwbgPFQU8Kg.yF.XCtOi  Homemade Mac and Cheese Casserole
#
#                                                                        ingredients  \
# rmK12Uau.ntP510KeImX506H6Mr6jTu  [4 skinless, boneless chicken breast halves AD...
# 5ZpZE8hSVdPk2ZXo1mZTyoPWJRSCPSm  [2 (10.75 ounce) cans condensed cream of mushr...
# clyYQv.CplpwJtjNaFGhx0VilNYqRxu  [1/2 cup packed brown sugar ADVERTISEMENT, 1/2...
# BmqFAmCrDHiKNwX.IQzb0U/v0mLlxFu  [1 cup butter, softened ADVERTISEMENT, 1 cup w...
# N.jCksRjB4MFwbgPFQU8Kg.yF.XCtOi  [8 ounces whole wheat rotini pasta ADVERTISEME...
#
#                                                                       instructions  \
# rmK12Uau.ntP510KeImX506H6Mr6jTu  Place the chicken, butter, soup, and onion in ...
# 5ZpZE8hSVdPk2ZXo1mZTyoPWJRSCPSm  In a slow cooker, mix cream of mushroom soup, ...
# clyYQv.CplpwJtjNaFGhx0VilNYqRxu  Preheat oven to 350 degrees F (175 degrees C)....
# BmqFAmCrDHiKNwX.IQzb0U/v0mLlxFu  Preheat oven to 350 degrees F (175 degrees C)....
# N.jCksRjB4MFwbgPFQU8Kg.yF.XCtOi  Preheat oven to 350 degrees F. Line a 2-quart ...
#
#                                                     picture_link
# rmK12Uau.ntP510KeImX506H6Mr6jTu  55lznCYBbs2mT8BTx6BTkLhynGHzM.S
# 5ZpZE8hSVdPk2ZXo1mZTyoPWJRSCPSm  QyrvGdGNMBA2lDdciY0FjKu.77MM0Oe
# clyYQv.CplpwJtjNaFGhx0VilNYqRxu  LVW1DI0vtlCrpAhNSEQysE9i/7rJG56
# BmqFAmCrDHiKNwX.IQzb0U/v0mLlxFu  0SO5kdWOV94j6EfAVwMMYRM3yNN8eRi
# N.jCksRjB4MFwbgPFQU8Kg.yF.XCtOi  YCnbhplMgiraW4rUXcybgSEZinSgljm

# %% [markdown]
# - check for missing values

# %%
data_recipes_raw_nosource_ar.isnull().sum().sum()
# Out:
# 1120

# %% [markdown]
# - check length of dataset, i.e., the amount of recipes presented in the dataset

# %%
len(data_recipes_raw_nosource_ar)
# Out:
# 39802

# %% [markdown]
# - read (4) recipes_raw_nosource_epi as DataFrames

# %%
data_recipes_raw_nosource_epi = pd.read_json('recipes_raw_nosource_epi.json')

# %%
data_recipes_raw_nosource_epi = data_recipes_raw_nosource_epi.transpose()
data_recipes_raw_nosource_epi.head()
# Out:
#                                                                        ingredients  \
# 05zEpbSqcs9E0rcnCJWyZ9OgdH0MLby  [12 egg whites, 12 egg yolks, 1 1/2 cups sugar...
# mF5SZmoqxF4WtIlhLRvzuKk.z6s7P2S  [18 fresh chestnuts, 2 1/2 pounds veal stew me...
# oQV5D7cVbCFwmrDs3pBUv2y.AG0WV26  [2 tablespoons unsalted butter, softened, 4 or...
# Z9seBJWaB5NkSp4DQHDnCAUBTwov/1u  [3/4 pound Stilton, crumbled (about 3 cups) an...
# bB3GxoAplVZeoX3fzWNWyeECtQFxw6G  [2 cups (about 9 1/2 ounces) whole almonds, to...
#
#                                                     picture_link  \
# 05zEpbSqcs9E0rcnCJWyZ9OgdH0MLby                             None
# mF5SZmoqxF4WtIlhLRvzuKk.z6s7P2S                             None
# oQV5D7cVbCFwmrDs3pBUv2y.AG0WV26  3xjktRst3I5lDZ2Z5kTOtqQyzZFFN9u
# Z9seBJWaB5NkSp4DQHDnCAUBTwov/1u                             None
# bB3GxoAplVZeoX3fzWNWyeECtQFxw6G                             None
#
#                                                                       instructions  \
# 05zEpbSqcs9E0rcnCJWyZ9OgdH0MLby  Beat the egg whites until stiff, gradually add...
# mF5SZmoqxF4WtIlhLRvzuKk.z6s7P2S  Preheat oven to 400°F. Using small sharp knife...
# oQV5D7cVbCFwmrDs3pBUv2y.AG0WV26  Preheat the oven to 350°F. Spread the softened...
# Z9seBJWaB5NkSp4DQHDnCAUBTwov/1u  In a food processor blend the Stilton, the cre...
# bB3GxoAplVZeoX3fzWNWyeECtQFxw6G  Position rack in center of oven and preheat to...
#
#                                                                              title
# 05zEpbSqcs9E0rcnCJWyZ9OgdH0MLby                                  Christmas Eggnog
# mF5SZmoqxF4WtIlhLRvzuKk.z6s7P2S                  Veal, Carrot and Chestnut Ragoût
# oQV5D7cVbCFwmrDs3pBUv2y.AG0WV26  Caramelized Bread Pudding with Chocolate and C...
# Z9seBJWaB5NkSp4DQHDnCAUBTwov/1u      Sherried Stilton and Green Peppercorn Spread
# bB3GxoAplVZeoX3fzWNWyeECtQFxw6G                        Almond-Chocolate Macaroons

# %% [markdown]
# - check for missing values

# %%
data_recipes_raw_nosource_epi.isnull().sum().sum()
# Out:
# 13204

# %% [markdown]
# - check length of dataset, i.e., the amount of recipes presented in the dataset

# %%
len(data_recipes_raw_nosource_epi)
# Out:
# 25323

# %% [markdown]
# - read (5) recipes_raw_nosource_fn as DataFrames

# %%
data_recipes_raw_nosource_fn = pd.read_json('recipes_raw_nosource_fn.json')

# %%
data_recipes_raw_nosource_fn = data_recipes_raw_nosource_fn.transpose()
data_recipes_raw_nosource_fn.head()
# Out:
#                                                                       instructions  \
# p3pKOD6jIHEcjf20CCXohP8uqkG5dGi  Toss ingredients lightly and spoon into a butt...
# S7aeOIrsrgT0jLP32jKGg4j.o9zi2DO  Watch how to make this recipe.\nSprinkle the s...
# o9MItV9txfoPsUQ4v8b0vh1.VdjwfsK  In a large saucepan, let the beans soak in eno...
# 5l1yTSYFifF/M2dfbD6DX28WWQpLWNK  Watch how to make this recipe.\nPreheat the ov...
# kRBQSWtqYWqtkb34FGeenBSbC32gIdO  Special equipment: sushi mat\nCook the brown r...
#
#                                                                        ingredients  \
# p3pKOD6jIHEcjf20CCXohP8uqkG5dGi  [1/2 cup celery, finely chopped, 1 small green...
# S7aeOIrsrgT0jLP32jKGg4j.o9zi2DO  [2 pounds skirt steak, cut into 1/2-inch dice,...
# o9MItV9txfoPsUQ4v8b0vh1.VdjwfsK  [1 1/2 cups dried black beans, picked over and...
# 5l1yTSYFifF/M2dfbD6DX28WWQpLWNK  [1 1/4 pounds ground chuck, One 15-ounce can t...
# kRBQSWtqYWqtkb34FGeenBSbC32gIdO  [1 cup rice, brown, medium-grain, cooked, 1/2-...
#
#                                                           title  \
# p3pKOD6jIHEcjf20CCXohP8uqkG5dGi  Grammie Hamblet's Deviled Crab
# S7aeOIrsrgT0jLP32jKGg4j.o9zi2DO    Infineon Raceway Baked Beans
# o9MItV9txfoPsUQ4v8b0vh1.VdjwfsK     Southwestern Black Bean Dip
# 5l1yTSYFifF/M2dfbD6DX28WWQpLWNK          Sour Cream Noodle Bake
# kRBQSWtqYWqtkb34FGeenBSbC32gIdO                Sushi Renovation
#
#                                                     picture_link
# p3pKOD6jIHEcjf20CCXohP8uqkG5dGi                             None
# S7aeOIrsrgT0jLP32jKGg4j.o9zi2DO  Ja5uaD8Q7m7vvtWwk2.48dr1eCre/qi
# o9MItV9txfoPsUQ4v8b0vh1.VdjwfsK                             None
# 5l1yTSYFifF/M2dfbD6DX28WWQpLWNK  nm/WxalB.VjEZSa0iX9RuZ8xI51Y7bS
# kRBQSWtqYWqtkb34FGeenBSbC32gIdO                             None

# %% [markdown]
# - check for missing values

# %%
data_recipes_raw_nosource_fn.isnull().sum().sum()
# Out:
# 30024

# %% [markdown]
# - check length of dataset, i.e., the amount of recipes presented in the dataset

# %%
len(data_recipes_raw_nosource_fn)
# Out:
# 60039

# %% [markdown]
# - combine all three recipes_raw_nosource_{recipe_sources} Datasets

# %%
data_recipes_raw_nosource = [data_recipes_raw_nosource_ar, data_recipes_raw_nosource_epi, data_recipes_raw_nosource_fn]
data_recipes_raw_nosource_instructions = pd.concat(data_recipes_raw_nosource)
data_recipes_raw_nosource_instructions = data_recipes_raw_nosource_instructions.reset_index(drop=True)

# %% [markdown]
# - drop irrelevant columns for training dataset

# %%
data_recipes_raw_nosource_instructions = data_recipes_raw_nosource_instructions.drop(['title', 'picture_link', 'ingredients'], axis=1)

# %%
data_recipes_raw_nosource_instructions.head()
# Out:
#                                         instructions
# 0  Place the chicken, butter, soup, and onion in ...
# 1  In a slow cooker, mix cream of mushroom soup, ...
# 2  Preheat oven to 350 degrees F (175 degrees C)....
# 3  Preheat oven to 350 degrees F (175 degrees C)....
# 4  Preheat oven to 350 degrees F. Line a 2-quart ...

# %% [markdown]
# Examine the combined recipes_raw_nosource_{recipe_sources} dataset:

# %%
data_recipes_raw_nosource_instructions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125164 entries, 0 to 125163
# Data columns (total 1 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   instructions  124473 non-null  object
# dtypes: object(1)
# memory usage: 978.0+ KB

# %% [markdown]
# - check for missing values

# %%
data_recipes_raw_nosource_instructions.isnull().sum().sum()
# Out:
# 691

# %% [markdown]
# - check length of combined dataset, i.e., the amount of recipes presented in the dataset

# %%
len(data_recipes_raw_nosource_instructions)
# Out:
# 125164

# %%
sum_len_data_recipes_raw_nosource = len(data_recipes_raw_nosource_ar) + len(data_recipes_raw_nosource_epi) + len(data_recipes_raw_nosource_fn)
sum_len_data_recipes_raw_nosource
# Out:
# 125164

# %% [markdown]
# #### 1.1.2 Initial Training Dataset

# %% [markdown]
# The training dataset consists of the three above created DataFrames:
#
#        (1) data_RecipeNLG_instructions
#        (2) data_recipes_raw_nosource_instructions
#        (3) data_recipes_instructions
#
# - combine the three datasets

# %%
datasets = [data_RecipeNLG_instructions, data_recipes_raw_nosource_instructions, data_recipes_instructions]

datasets_combined = pd.concat(datasets)
datasets_combined.head()
# Out:
#                                         instructions
# 0  ["In a heavy 2-quart saucepan, mix brown sugar...
# 1  ["Place chipped beef on bottom of baking dish....
# 2  ["In a slow cooker, combine all ingredients. C...
# 3  ["Boil and debone chicken.", "Put bite size pi...
# 4  ["Combine first four ingredients and press in ...

# %% [markdown]
# - check the length of the combined dataset

# %%
len(datasets_combined)
# Out:
# 2878823

# %% [markdown]
# ### 1.2 Data Preprocessing
#
# This chapter preprocesses the Training Data for further use. This includes the following steps:
#
# 1.  Handle missing values
# 2.	Convert letters into lower case
# 3.	Remove punctuations and numerical digits
# 4.	Remove stopwords
# 5.	Remove symbols
# 6.	Remove duplicates
# 7.	Detect n-grams
# 8.	Replace individual words in instruction text with n-grams

# %% [markdown]
# #### 1.2.1 Handle missing values
#
# - search for NaN/NA/None values in the training data

# %%
datasets_combined['instructions'].replace('', np.nan, inplace=True)

# %%
datasets_combined['instructions'].isnull().values.any()
# Out:
# True

# %%
datasets_combined['instructions'].isnull().sum().sum()
# Out:
# 714

# %% [markdown]
# - remove Nan/NA/None values

# %%
datasets_combined.dropna(subset = ["instructions"], inplace=True)

# %%
datasets_combined[datasets_combined['instructions'].notnull()]
# Out:
#                                              instructions
# 0       ["In a heavy 2-quart saucepan, mix brown sugar...
# 1       ["Place chipped beef on bottom of baking dish....
# 2       ["In a slow cooker, combine all ingredients. C...
# 3       ["Boil and debone chicken.", "Put bite size pi...
# 4       ["Combine first four ingredients and press in ...
# ...                                                   ...
# 522512  c("Preheat oven to 350&deg;F Grease an 8x8 cak...
# 522513  c("Position rack in center of oven and preheat...
# 522514  c("heat half and half and heavy cream to a sim...
# 522515  c("In a small bowl, combine mayo and wasabi pa...
# 522516  c("Mix sausage, panko, egg yolk and Wocestersh...
#
# [2878109 rows x 1 columns]

# %% [markdown]
# - check if NaN/NA/None values were removed successfully

# %%
is_NaN = datasets_combined.isnull()
row_has_NaN = is_NaN.any(axis=1)
rows_with_NaN = datasets_combined[row_has_NaN]

# %%
rows_with_NaN
# Out:
# Empty DataFrame
# Columns: [instructions]
# Index: []

# %%
datasets_combined.isnull().values.any()
# Out:
# False

# %% [markdown]
# - check lenght of dataset

# %%
len(datasets_combined)
# Out:
# 2878109

# %% [markdown]
# #### 1.2.2 Remove Stopwords
#
# - define individual stopwords

# %%
to_remove_instructions = [
    'c',
    'cup',
    'cups',
    'f',
    'gram',
    'grams',
    'inch',
    'inches',
    'kg',
    'kilogram',
    'kilograms',
    'mg'
    'miligram',
    'miligrams',
    'o',
    'ounce',
    'ounces',
    'oz',
    'pkg',
    'pound',
    'pounds',
    'pwdr',
    't',
    'tablespoons',
    'tablespoon',
    'tblsp',
    'tbs',
    'tbsp',
    'tbspful',
    'tbspn',
    'tbspoon',
    'tbsps',
    'teaspoon',
    'teaspoons',
    'tsp',
    'tsps',
    'ub',
    'x'
]

# %%
instructions_stopwords = STOPWORDS.union(set(to_remove_instructions))

# %% [markdown]
# - define function for stopword removal

# %%
def remove_instructions_stopwords(s):
    s = utils.to_unicode(s)
    return " ".join(w for w in s.split() if w not in instructions_stopwords)

# %% [markdown]
# #### 1.2.3 Remove Symbols
#
# - define individual symbols

# %%
to_remove_symbols = [
    '½',
    '⅓',
    '¼',
    '¾',
    '⅞',
    '©',
    '®',
    '™',
    '°f'
]

# %% [markdown]
# - define function for symbol removal

# %%
def remove_symbols(text):
    regex = re.compile("(%s)" % "|".join(map(re.escape, to_remove_symbols)))
    return regex.sub("", text)

# %% [markdown]
# #### 1.2.3 Preprocess Training Data

# %%
def preprocess_instructions(text):
    text = text.lower()
    text = pp.strip_punctuation(text)
    text = pp.strip_numeric(text)
    text = remove_instructions_stopwords(text)
    text = remove_symbols(text)
    
    return text

# %% [markdown]
# - apply preprocessing function to the training data

# %%
# %%time
datasets_combined['instructions_pp'] = datasets_combined['instructions'].apply(preprocess_instructions)
# Out:
# CPU times: user 2min 33s, sys: 864 ms, total: 2min 34s
# Wall time: 2min 35s

# %% [markdown]
# - drop not preprocessed column

# %%
dataset_pp = datasets_combined.drop(['instructions'], axis=1)
dataset_pp
# Out:
#                                           instructions_pp
# 0       heavy quart saucepan mix brown sugar nuts evap...
# 1       place chipped beef baking dish place chicken b...
# 2       slow cooker combine ingredients cover cook low...
# 3       boil debone chicken bite size pieces average s...
# 4       combine ingredients press ungreased pan melt c...
# ...                                                   ...
# 522512  preheat oven deg grease cake pan recipe uses m...
# 522513  position rack center oven preheat  place beef ...
# 522514  heat half half heavy cream simmer add sugar re...
# 522515  small bowl combine mayo wasabi paste stir addi...
# 522516  mix sausage panko egg yolk wocestershire sauce...
#
# [2878109 rows x 1 columns]

# %% [markdown]
# #### 1.2.4 Remove Duplicates
#
# - remove duplicates from the training data, based on the preprocessed instruction text (instructions_pp)

# %%
dataset_pp = dataset_pp.drop_duplicates(subset=['instructions_pp'], keep='first')

# %%
sum_duplicates = len(datasets_combined) - len(dataset_pp)
sum_duplicates
# Out:
# 524667

# %% [markdown]
# #### 1.2.5 Handle missing values

# %% [markdown]
# - check again for missing values, which may appear after the preprocessing

# %%
dataset_pp['instructions_pp'].replace('', np.nan, inplace=True)

# %%
dataset_pp['instructions_pp'].isnull().values.any()
# Out:
# True

# %%
dataset_pp['instructions_pp'].isnull().sum().sum()
# Out:
# 1

# %% [markdown]
# - remove Nan/NA/None values

# %%
dataset_pp.dropna(subset = ["instructions_pp"], inplace=True)

# %%
len(dataset_pp)
# Out:
# 2353441

# %% [markdown]
# #### 1.2.6 Detect n-grams
#
# For the final training data, n-grams in the instructions text need to be generated in order to identify multi-word ingredients.

# %%
dataset_pp
# Out:
#                                           instructions_pp
# 0       heavy quart saucepan mix brown sugar nuts evap...
# 1       place chipped beef baking dish place chicken b...
# 2       slow cooker combine ingredients cover cook low...
# 3       boil debone chicken bite size pieces average s...
# 4       combine ingredients press ungreased pan melt c...
# ...                                                   ...
# 522511  beat eggs add oil water pumpkin mix add baking...
# 522512  preheat oven deg grease cake pan recipe uses m...
# 522513  position rack center oven preheat  place beef ...
# 522514  heat half half heavy cream simmer add sugar re...
# 522516  mix sausage panko egg yolk wocestershire sauce...
#
# [2353441 rows x 1 columns]

# %% [markdown]
# Train two phrases models on the instructions of the training data in order to identify n-gram ingredients:
#
# The parameter threshold defines the forming of the phrases. A higher threshold implies fewer phrases.

# %% [markdown]
# - first phrases model training

# %%
instructions_pp_split = dataset_pp['instructions_pp'].apply(lambda x: x.split())

# %%
# %%time
phrases_bigrams = Phrases(instructions_pp_split, threshold=4)
# Out:
# CPU times: user 2min 46s, sys: 15 s, total: 3min 1s
# Wall time: 3min 14s

# %% [markdown]
# - second phrases model training

# %%
# %%time
phrases_ngrams = Phrases(phrases_bigrams[instructions_pp_split], threshold = 2)
# Out:
# CPU times: user 6min 42s, sys: 19.5 s, total: 7min 1s
# Wall time: 7min 18s

# %% [markdown]
# #### 1.2.7 Replace individual words in instruction text with n-grams

# %% [markdown]
# Extract the generated n-grams and replace them within the instruction text in the training data:
#
# - export the generated n-grams

# %%
exported_phrases = phrases_ngrams.export_phrases()
ngram_ingredients = list(exported_phrases.keys())

# %%
len(ngram_ingredients)
# Out:
# 97241

# %% [markdown]
# - create dictonary for the n-grams

# %%
ngram_dict = {}

for ngram in ngram_ingredients:
    ngram_dict[ngram] = [ngram.replace("_", " ")]

# %%
ngram_dict
# Out:
# {'quart_saucepan': ['quart saucepan'],
#  'evaporated_milk': ['evaporated milk'],
#  'wax_paper': ['wax paper'],
#  'let_stand': ['let stand'],
#  'wax_paper_let_stand': ['wax paper let stand'],
#  'chipped_beef': ['chipped beef'],
#  'baking_dish': ['baking dish'],
#  'bake_uncovered': ['bake uncovered'],
#  'slow_cooker': ['slow cooker'],
#  'yields_servings': ['yields servings'],
#  'debone_chicken': ['debone chicken'],
#  'bite_size': ['bite size'],
#  'bite_size_pieces': ['bite size pieces'],
#  'average_size': ['average size'],
#  'casserole_dish': ['casserole dish'],
#  'mushroom_soup': ['mushroom soup'],
#  'according_instructions': ['according instructions'],
#  'according_instructions_box': ['according instructions box'],
#  'shredded_cheese': ['shredded cheese'],
#  'chocolate_chips': ['chocolate chips'],
#  'melt_chocolate_chips': ['melt chocolate chips'],
#  'gets_hard': ['gets hard'],
#  'prick_times': ['prick times'],
#  'times_fork': ['times fork'],
#  'paper_towel': ['paper towel'],
#  'ready_eat': ['ready eat'],
#  'let_cool': ['let cool'],
#  'cool_handle': ['cool handle'],
#  'half_lengthwise': ['half lengthwise'],
#  'scoop_pulp': ['scoop pulp'],
#  'ground_beef': ['ground beef'],
#  'set_aside': ['set aside'],
#  'added_later': ['added later'],
#  'melt_butter': ['melt butter'],
#  'stirring_constantly': ['stirring constantly'],
#  'minute_stirring_constantly': ['minute stirring constantly'],
#  'heat_stirring_constantly': ['heat stirring constantly'],
#  'thickened_bubbly': ['thickened bubbly'],
#  'salt_pepper': ['salt pepper'],
#  'sour_cream': ['sour cream'],
#  'sour_cream_desired': ['sour cream desired'],
#  'green_onions': ['green onions'],
#  'alternately_buttermilk': ['alternately buttermilk'],
#  'melted_butter': ['melted butter'],
#  'steak_strips': ['steak strips'],
#  'worcestershire_sauce': ['worcestershire sauce'],
#  'green_peppers': ['green peppers'],
#  'cool_whip': ['cool whip'],
#  'condensed_milk': ['condensed milk'],
#  'squeeze_lemons': ['squeeze lemons'],
#  'graham_cracker': ['graham cracker'],
#  'pour_graham_cracker': ['pour graham cracker'],
#  'graham_cracker_crust': ['graham cracker crust'],
#  'chill_overnight': ['chill overnight'],
#  'makes_pies': ['makes pies'],
#  'ginger_ale': ['ginger ale'],
#  'add_ginger_ale': ['add ginger ale'],
#  'dissolve_gelatin': ['dissolve gelatin'],
#  'dissolve_gelatin_boiling': ['dissolve gelatin boiling'],
#  'boiling_water': ['boiling water'],
#  'measured_liquid': ['measured liquid'],
#  'almond_extract': ['almond extract'],
#  'mold_chill': ['mold chill'],
#  'chill_firm': ['chill firm'],
#  'hours_overnight': ['hours overnight'],
#  'overnight_unmold': ['overnight unmold'],
#  'peanut_butter': ['peanut butter'],
#  'roll_balls': ['roll balls'],
#  'cookie_sheet': ['cookie sheet'],
#  'paraffin_double': ['paraffin double'],
#  'paraffin_double_boiler': ['paraffin double boiler'],
#  'boiler_toothpick': ['boiler toothpick'],
#  'chocolate_chip': ['chocolate chip'],
#  'look_like': ['look like'],
#  'look_like_buckeyes': ['look like buckeyes'],
#  'chicken_wings': ['chicken wings'],
#  'barbecue_sauce': ['barbecue sauce'],
#  'microwave_high': ['microwave high'],
#  'taco_sauce': ['taco sauce'],
#  'sour_cream_cream': ['sour cream cream'],
#  'cream_cheese': ['cream cheese'],
#  'drain_fat': ['drain fat'],
#  'taco_seasoning': ['taco seasoning'],
#  'raw_vegetables': ['raw vegetables'],
#  'freeze_firm': ['freeze firm'],
#  'stir_constantly': ['stir constantly'],
#  'baked_crust': ['baked crust'],
#  'continue_layering': ['continue layering'],
#  'whipped_cream': ['whipped cream'],
#  'according_directions': ['according directions'],
#  'tough_ends': ['tough ends'],
#  'florets_stems': ['florets stems'],
#  'refrigerate_hours': ['refrigerate hours'],
#  'makes_servings': ['makes servings'],
#  'jell_boiling': ['jell boiling'],
#  'nuts_raisins': ['nuts raisins'],
#  'sift_dry': ['sift dry'],
#  'dry_ingredients': ['dry ingredients'],
#  'greased_floured': ['greased floured'],
#  'loaf_pan': ['loaf pan'],
#  'tube_pan': ['tube pan'],
#  'turkey_breast': ['turkey breast'],
#  'skin_bones': ['skin bones'],
#  'longer_marinates': ['longer marinates'],
#  'cooking_time': ['cooking time'],
#  'food_processor': ['food processor'],
#  'use_food_processor': ['use food processor'],
#  'jars_seal': ['jars seal'],
#  'yields_quarts': ['yields quarts'],
#  'press_firmly': ['press firmly'],
#  'bake_preheated': ['bake preheated'],
#  'slicing_makes_servings': ['slicing makes servings'],
#  'technique_works': ['technique works'],
#  'tomato_sauce': ['tomato sauce'],
#  'stirring_occasionally': ['stirring occasionally'],
#  'unsweetened_chocolate': ['unsweetened chocolate'],
#  'kidney_beans': ['kidney beans'],
#  'kidney_beans_salsa': ['kidney beans salsa'],
#  'bring_boil': ['bring boil'],
#  'bring_boil_reduce': ['bring boil reduce'],
#  'reduce_heat': ['reduce heat'],
#  'mixing_bowl': ['mixing bowl'],
#  'cool_lukewarm': ['cool lukewarm'],
#  'floured_board': ['floured board'],
#  'biscuit_cutter': ['biscuit cutter'],
#  'cut_biscuit_cutter': ['cut biscuit cutter'],
#  'brush_tops': ['brush tops'],
#  'melted_oleo': ['melted oleo'],
#  'let_rise': ['let rise'],
#  'yield_dozen': ['yield dozen'],
#  'slice_bananas': ['slice bananas'],
#  'double_recipe': ['double recipe'],
#  'cherry_pie': ['cherry pie'],
#  'beat_eggs': ['beat eggs'],
#  'knife_inserted': ['knife inserted'],
#  'minutes_knife_inserted': ['minutes knife inserted'],
#  'center_comes': ['center comes'],
#  'knife_inserted_center_comes': ['knife inserted center comes'],
#  'center_comes_clean': ['center comes clean'],
#  'cut_squares': ['cut squares'],
#  'drained_tuna': ['drained tuna'],
#  'parmesan_cheese': ['parmesan cheese'],
#  'sour_cream_soup': ['sour cream soup'],
#  'marinate_overnight': ['marinate overnight'],
#  'salad_supreme': ['salad supreme'],
#  'zesty_italian': ['zesty italian'],
#  'zesty_italian_dressing': ['zesty italian dressing'],
#  'reserving_juice': ['reserving juice'],
#  'boil_stirring_constantly': ['boil stirring constantly'],
#  'cool_slightly': ['cool slightly'],
#  'coarsely_chop': ['coarsely chop'],
#  'pear_halves': ['pear halves'],
#  'medium_speed': ['medium speed'],
#  'electric_mixer': ['electric mixer'],
#  'speed_electric_mixer': ['speed electric mixer'],
#  'electric_mixer_smooth': ['electric mixer smooth'],
#  'oiled_mold': ['oiled mold'],
#  'pyrex_dish': ['pyrex dish'],
#  'watermelon_rind': ['watermelon rind'],
#  'overnight_morning': ['overnight morning'],
#  'hot_sterilized': ['hot sterilized'],
#  'seal_hot_sterilized': ['seal hot sterilized'],
#  'makes_pints': ['makes pints'],
#  'jars_makes_pints': ['jars makes pints'],
#  'black_pepper': ['black pepper'],
#  'vegetables_tender': ['vegetables tender'],
#  'granulated_sugar': ['granulated sugar'],
#  'baking_powder': ['baking powder'],
#  'alternately_milk': ['alternately milk'],
#  'greased_square': ['greased square'],
#  'square_baking': ['square baking'],
#  'dissolve_yeast': ['dissolve yeast'],
#  'dissolve_yeast_warm': ['dissolve yeast warm'],
#  'melted_margarine': ['melted margarine'],
#  'crescent_triangle': ['crescent triangle'],
#  'muffin_tin': ['muffin tin'],
#  'spring_touched': ['spring touched'],
#  'overbake_cool': ['overbake cool'],
#  'cool_completely': ['cool completely'],
#  'melt_margarine': ['melt margarine'],
#  'onions_celery': ['onions celery'],
#  'curry_powder': ['curry powder'],
#  'grated_cheese': ['grated cheese'],
#  'sift_flour': ['sift flour'],
#  'egg_yolks': ['egg yolks'],
#  'light_fluffy': ['light fluffy'],
#  'sifted_dry': ['sifted dry'],
#  'shape_balls': ['shape balls'],
#  'wooden_spoon': ['wooden spoon'],
#  'wooden_spoon_handle': ['wooden spoon handle'],
#  'lightly_greased': ['lightly greased'],
#  'baking_sheets': ['baking sheets'],
#  'golden_brown': ['golden brown'],
#  'excess_fat': ['excess fat'],
#  'let_sit': ['let sit'],
#  'cabbage_carrot': ['cabbage carrot'],
#  'single_layer': ['single layer'],
#  'single_layer_baking': ['single layer baking'],
#  'fish_flakes': ['fish flakes'],
#  'easily_fork': ['easily fork'],
#  'sugar_dissolved': ['sugar dissolved'],
#  'quart_casserole': ['quart casserole'],
#  'crisp_tender': ['crisp tender'],
#  'lump_crab': ['lump crab'],
#  'ahead_time': ['ahead time'],
#  'dinner_plates': ['dinner plates'],
#  'tortilla_chips': ['tortilla chips'],
#  'form_balls': ['form balls'],
#  'chill_hours': ['chill hours'],
#  'powdered_sugar': ['powdered sugar'],
#  'waxed_paper': ['waxed paper'],
#  'drop_waxed_paper': ['drop waxed paper'],
#  'waxed_paper_let': ['waxed paper let'],
#  'chopped_nuts': ['chopped nuts'],
#  'lemon_juice': ['lemon juice'],
#  'balls_roll': ['balls roll'],
#  'chopped_peanuts': ['chopped peanuts'],
#  'container_freeze': ['container freeze'],
#  'egg_whites': ['egg whites'],
#  'beat_egg_whites': ['beat egg whites'],
#  'stiff_peaks': ['stiff peaks'],
#  'egg_whites_stiff_peaks': ['egg whites stiff peaks'],
#  'stiff_peaks_form': ['stiff peaks form'],
#  'beater_lifted': ['beater lifted'],
#  'cake_pans': ['cake pans'],
#  'pour_greased_floured': ['pour greased floured'],
#  'greased_floured_tube': ['greased floured tube'],
#  'peel_dice': ['peel dice'],
#  'salted_water': ['salted water'],
#  'paper_towels': ['paper towels'],
#  'dry_paper_towels': ['dry paper towels'],
#  'sour_cream_cheese': ['sour cream cheese'],
#  'quart_casserole_dish': ['quart casserole dish'],
#  'crush_cornflakes': ['crush cornflakes'],
#  'vanilla_wafer': ['vanilla wafer'],
#  'forms_hard': ['forms hard'],
#  'hard_ball': ['hard ball'],
#  'cold_water': ['cold water'],
#  'stiffly_beaten': ['stiffly beaten'],
#  'stiffly_beaten_egg_whites': ['stiffly beaten egg whites'],
#  'beating_constantly': ['beating constantly'],
#  'cornflake_crumbs': ['cornflake crumbs'],
#  'season_salt': ['season salt'],
#  'chicken_broth': ['chicken broth'],
#  'cook_stirring_constantly': ['cook stirring constantly'],
#  'slightly_thickened': ['slightly thickened'],
#  'beaten_egg': ['beaten egg'],
#  'warmed_mugs': ['warmed mugs'],
#  'dash_nutmeg': ['dash nutmeg'],
#  'recipe_doubled': ['recipe doubled'],
#  'number_guests': ['number guests'],
#  'sheets_waxed_paper': ['sheets waxed paper'],
#  'heavy_duty': ['heavy duty'],
#  'plastic_wrap': ['plastic wrap'],
#  'plastic_wrap_flatten': ['plastic wrap flatten'],
#  'flatten_thickness': ['flatten thickness'],
#  'meat_mallet': ['meat mallet'],
#  'thickness_meat_mallet': ['thickness meat mallet'],
#  'rolling_pin': ['rolling pin'],
#  'meat_mallet_rolling_pin': ['meat mallet rolling pin'],
#  'grill_rack': ['grill rack'],
#  'cooking_spray': ['cooking spray'],
#  'basting_frequently': ['basting frequently'],
#  'soy_sauce': ['soy sauce'],
#  'serving_platter': ['serving platter'],
#  'yields_servings_calories': ['yields servings calories'],
#  'refrigerator_overnight': ['refrigerator overnight'],
#  'cheddar_cheese': ['cheddar cheese'],
#  'food_processor_blender': ['food processor blender'],
#  'grind_cranberries': ['grind cranberries'],
#  'according_package': ['according package'],
#  'according_package_directions': ['according package directions'],
#  'begins_thicken': ['begins thicken'],
#  'day_ahead': ['day ahead'],
#  'keeps_refrigerator': ['keeps refrigerator'],
#  'keeps_refrigerator_days': ['keeps refrigerator days'],
#  'shortly_serving': ['shortly serving'],
#  'double_boiler': ['double boiler'],
#  'ingredients_double_boiler': ['ingredients double boiler'],
#  'corn_chips': ['corn chips'],
#  'finger_funnel': ['finger funnel'],
#  'hold_finger_funnel': ['hold finger funnel'],
#  'spiral_motion': ['spiral motion'],
#  'drain_paper_towel': ['drain paper towel'],
#  'powdered_sugar_serve': ['powdered sugar serve'],
#  'confectioners_sugar': ['confectioners sugar'],
#  'confectioners_sugar_cocoa': ['confectioners sugar cocoa'],
#  'cheddar_cheeses': ['cheddar cheeses'],
#  'roll_ball': ['roll ball'],
#  'dissolve_jello': ['dissolve jello'],
#  'dissolve_jello_boiling': ['dissolve jello boiling'],
#  'crushed_pineapple': ['crushed pineapple'],
#  'apricot_baby': ['apricot baby'],
#  'baby_food': ['baby food'],
#  'stiff_fold': ['stiff fold'],
#  'partially_set': ['partially set'],
#  'quart_mold': ['quart mold'],
#  'room_temperature': ['room temperature'],
#  'high_speed': ['high speed'],
#  'speed_blended': ['speed blended'],
#  'batter_greased_floured': ['batter greased floured'],
#  'bundt_pan': ['bundt pan'],
#  'unroll_crescent': ['unroll crescent'],
#  'unroll_crescent_rolls': ['unroll crescent rolls'],
#  'bell_pepper': ['bell pepper'],
#  'bell_pepper_oil': ['bell pepper oil'],
#  'onions_transparent': ['onions transparent'],
#  'crock_pot': ['crock pot'],
#  'crock_pot_cook': ['crock pot cook'],
#  'bouillon_cubes': ['bouillon cubes'],
#  'angel_hair': ['angel hair'],
#  'serves_people': ['serves people'],
#  'balls_flatten': ['balls flatten'],
#  'flatten_fork': ['flatten fork'],
#  'ungreased_cookie': ['ungreased cookie'],
#  'ungreased_cookie_sheet': ['ungreased cookie sheet'],
#  'makes_dozen': ['makes dozen'],
#  'quick_easy': ['quick easy'],
#  'eagle_brand': ['eagle brand'],
#  'eagle_brand_milk': ['eagle brand milk'],
#  'bits_brickle': ['bits brickle'],
#  'cut_bars': ['cut bars'],
#  'non_stick': ['non stick'],
#  'non_stick_pan': ['non stick pan'],
#  'preheat_oven': ['preheat oven'],
#  'frying_pan': ['frying pan'],
#  'lightly_salted': ['lightly salted'],
#  'salted_boiling': ['salted boiling'],
#  'bacon_crisp': ['bacon crisp'],
#  'reserve_drippings': ['reserve drippings'],
#  'bacon_drippings': ['bacon drippings'],
#  'let_stand_room_temperature': ['let stand room temperature'],
#  'room_temperature_hours': ['room temperature hours'],
#  'store_airtight': ['store airtight'],
#  'ingredients_store_airtight': ['ingredients store airtight'],
#  'store_airtight_container': ['store airtight container'],
#  'ready_serve': ['ready serve'],
#  'great_winter': ['great winter'],
#  'spray_pam': ['spray pam'],
#  'cookie_cutters': ['cookie cutters'],
#  'cut_cookie_cutters': ['cut cookie cutters'],
#  'makes_approximately': ['makes approximately'],
#  'approximately_dozen': ['approximately dozen'],
#  'squeeze_juice': ['squeeze juice'],
#  'juice_lime': ['juice lime'],
#  'brandy_triple': ['brandy triple'],
#  'brandy_triple_sec': ['brandy triple sec'],
#  'long_handled': ['long handled'],
#  'bell_peppers': ['bell peppers'],
#  'bell_peppers_soft': ['bell peppers soft'],
#  'oat_mixture': ['oat mixture'],
#  'baking_sheet': ['baking sheet'],
#  'chinese_noodles': ['chinese noodles'],
#  'form_ball': ['form ball'],
#  'chopped_pecans': ['chopped pecans'],
#  'assorted_crackers': ['assorted crackers'],
#  'hands_form': ['hands form'],
#  'refrigerate_days': ['refrigerate days'],
#  'sprinkle_paprika': ['sprinkle paprika'],
#  'ritz_crackers': ['ritz crackers'],
#  'shells_according_package': ['shells according package'],
#  'directions_drain': ['directions drain'],
#  'rinse_cold': ['rinse cold'],
#  'microwave_safe': ['microwave safe'],
#  'quart_microwave_safe': ['quart microwave safe'],
#  'low_wattage': ['low wattage'],
#  'dot_margarine': ['dot margarine'],
#  'order_given': ['order given'],
#  'ingredients_order_given': ['ingredients order given'],
#  'marinate_hours': ['marinate hours'],
#  'longer_sits': ['longer sits'],
#  'better_gets': ['better gets'],
#  'making_sure': ['making sure'],
#  'shape_ball': ['shape ball'],
#  'lettuce_leaf': ['lettuce leaf'],
#  'batter_lumpy': ['batter lumpy'],
#  'moistened_batter_lumpy': ['moistened batter lumpy'],
#  'forms_ball': ['forms ball'],
#  'time_beating': ['time beating'],
#  'eggs_time_beating': ['eggs time beating'],
#  'satin_like': ['satin like'],
#  'pastry_bag': ['pastry bag'],
#  'star_tip': ['star tip'],
#  'doughnut_shape': ['doughnut shape'],
#  'greased_cookie_sheet': ['greased cookie sheet'],
#  'cookie_sheet_bake': ['cookie sheet bake'],
#  'puffed_browned': ['puffed browned'],
#  'vegetable_oil': ['vegetable oil'],
#  'chili_powder': ['chili powder'],
#  'roasting_pan': ['roasting pan'],
#  'ingredients_including': ['ingredients including'],
#  'including_juices': ['including juices'],
#  'bringing_boil': ['bringing boil'],
#  'directed_package': ['directed package'],
#  'store_refrigerator': ['store refrigerator'],
#  'preheated_oven': ['preheated oven'],
#  'heavy_kettle': ['heavy kettle'],
#  'chicken_stock': ['chicken stock'],
#  'bay_leaf': ['bay leaf'],
#  'worcestershire_sauce_bay_leaf': ['worcestershire sauce bay leaf'],
#  'bay_leaf_garlic': ['bay leaf garlic'],
#  'french_bread': ['french bread'],
#  'slice_swiss': ['slice swiss'],
#  'swiss_cheese': ['swiss cheese'],
#  'unbaked_pie': ['unbaked pie'],
#  'unbaked_pie_shell': ['unbaked pie shell'],
#  'hand_mixer': ['hand mixer'],
#  'electric_beater': ['electric beater'],
#  'food_coloring': ['food coloring'],
#  'yellow_food_coloring': ['yellow food coloring'],
#  'insert_toothpick': ['insert toothpick'],
#  'beat_egg_yolks': ['beat egg yolks'],
#  'pie_shell': ['pie shell'],
#  'baked_pie_shell': ['baked pie shell'],
#  'tater_tots': ['tater tots'],
#  'tater_tots_mix': ['tater tots mix'],
#  'tater_tots_sprinkle': ['tater tots sprinkle'],
#  'heavy_saucepan': ['heavy saucepan'],
#  'pastry_shell': ['pastry shell'],
#  'ice_cream': ['ice cream'],
#  'easy_tasty': ['easy tasty'],
#  'pie_crusts': ['pie crusts'],
#  'watch_closely': ['watch closely'],
#  'caramel_topping': ['caramel topping'],
#  'cauliflower_broccoli': ['cauliflower broccoli'],
#  'carrots_celery': ['carrots celery'],
#  'cherry_tomatoes': ['cherry tomatoes'],
#  'drain_set_aside': ['drain set aside'],
#  'melt_oleo': ['melt oleo'],
#  'cottage_cheese': ['cottage cheese'],
#  'cottage_cheese_broccoli': ['cottage cheese broccoli'],
#  'green_beans': ['green beans'],
#  'italian_seasoning': ['italian seasoning'],
#  'bay_leaf_italian_seasoning': ['bay leaf italian seasoning'],
#  'changes_color': ['changes color'],
#  'tomato_juice': ['tomato juice'],
#  'oleo_cocoa': ['oleo cocoa'],
#  'punch_holes': ['punch holes'],
#  'bars_store': ['bars store'],
#  'store_loosely': ['store loosely'],
#  'loosely_covered': ['loosely covered'],
#  'candy_reaches': ['candy reaches'],
#  'reaches_soft': ['reaches soft'],
#  'ball_stage': ['ball stage'],
#  'soft_ball_stage': ['soft ball stage'],
#  'ball_dropped': ['ball dropped'],
#  'soft_ball_dropped': ['soft ball dropped'],
#  'drop_wax_paper': ['drop wax paper'],
#  'wax_paper_cool': ['wax paper cool'],
#  'vanilla_wafers': ['vanilla wafers'],
#  'gelatine_dissolves': ['gelatine dissolves'],
#  'baked_pie': ['baked pie'],
#  'pie_shells': ['pie shells'],
#  'italian_bread': ['italian bread'],
#  'bread_slices': ['bread slices'],
#  'refrigerate_overnight': ['refrigerate overnight'],
#  'peanut_butter_margarine': ['peanut butter margarine'],
#  'powdered_sugar_added': ['powdered sugar added'],
#  'entire_box': ['entire box'],
#  'wrappers_tamales': ['wrappers tamales'],
#  'spanish_rice': ['spanish rice'],
#  'potato_flakes': ['potato flakes'],
#  'soft_elastic': ['soft elastic'],
#  'sounds_hollow': ['sounds hollow'],
#  'bread_sounds_hollow': ['bread sounds hollow'],
#  'sounds_hollow_tapped': ['sounds hollow tapped'],
#  'rises_browns': ['rises browns'],
#  'artichoke_hearts': ['artichoke hearts'],
#  'slotted_spoon': ['slotted spoon'],
#  'slotted_spoon_transfer': ['slotted spoon transfer'],
#  'stirring_frequently': ['stirring frequently'],
#  'instant_pudding': ['instant pudding'],
#  'muffin_tins': ['muffin tins'],
#  'greased_muffin_tins': ['greased muffin tins'],
#  'smooth_creamy': ['smooth creamy'],
#  'muffin_pans': ['muffin pans'],
#  'makes_muffins': ['makes muffins'],
#  'chicken_breasts': ['chicken breasts'],
#  'lay_chicken_breasts': ['lay chicken breasts'],
#  'blender_food_processor': ['blender food processor'],
#  'directions_box': ['directions box'],
#  'oblong_shape': ['oblong shape'],
#  'corned_beef': ['corned beef'],
#  'corned_beef_hash': ['corned beef hash'],
#  'sharp_knife': ['sharp knife'],
#  'sharp_knife_cut': ['sharp knife cut'],
#  'longer_period': ['longer period'],
#  'period_time': ['period time'],
#  'right_away': ['right away'],
#  'corn_flakes': ['corn flakes'],
#  'pie_crust': ['pie crust'],
#  'roll_thickness': ['roll thickness'],
#  'thickness_cut': ['thickness cut'],
#  'cookie_sheets': ['cookie sheets'],
#  'brown_hamburger': ['brown hamburger'],
#  'spaghetti_sauce': ['spaghetti sauce'],
#  'chopped_parsley': ['chopped parsley'],
#  'pie_plate': ['pie plate'],
#  'mashed_potatoes': ['mashed potatoes'],
#  'rotary_beater': ['rotary beater'],
#  'rotary_beater_beat': ['rotary beater beat'],
#  'egg_white': ['egg white'],
#  'ungreased_baking': ['ungreased baking'],
#  'mozzarella_cheese': ['mozzarella cheese'],
#  'sweetened_condensed': ['sweetened condensed'],
#  'sweetened_condensed_milk': ['sweetened condensed milk'],
#  'wafer_crumbs': ['wafer crumbs'],
#  'foil_lined': ['foil lined'],
#  'firm_cut_squares': ['firm cut squares'],
#  'according_directions_package': ['according directions package'],
#  'crushed_ritz': ['crushed ritz'],
#  'crushed_ritz_crackers': ['crushed ritz crackers'],
#  'light_brown': ['light brown'],
#  'onion_celery': ['onion celery'],
#  'chow_mein': ['chow mein'],
#  'minutes_chow_mein': ['minutes chow mein'],
#  'chow_mein_noodles': ['chow mein noodles'],
#  'hard_ball_stage': ['hard ball stage'],
#  'stage_candy': ['stage candy'],
#  'stage_candy_thermometer': ['stage candy thermometer'],
#  'melt_chocolate': ['melt chocolate'],
#  'candy_bars': ['candy bars'],
#  'cooking_vessel': ['cooking vessel'],
#  'ungreased_tube': ['ungreased tube'],
#  'pan_removable': ['pan removable'],
#  'baking_soda': ['baking soda'],
#  'creamed_mixture': ['creamed mixture'],
#  'miniature_muffin': ['miniature muffin'],
#  'miniature_muffin_pans': ['miniature muffin pans'],
#  'nonstick_spray': ['nonstick spray'],
#  'lightly_browned': ['lightly browned'],
#  'peanut_butter_cookie': ['peanut butter cookie'],
#  'crumbled_bacon': ['crumbled bacon'],
#  'cinnamon_nutmeg': ['cinnamon nutmeg'],
#  'alternately_applesauce': ['alternately applesauce'],
#  'greased_loaf': ['greased loaf'],
#  'hour_knife_inserted': ['hour knife inserted'],
#  'floured_surface': ['floured surface'],
#  'freezer_bags': ['freezer bags'],
#  'dutch_oven': ['dutch oven'],
#  'dutch_oven_place': ['dutch oven place'],
#  'electric_stove': ['electric stove'],
#  'gas_stove': ['gas stove'],
#  'nuts_cherries': ['nuts cherries'],
#  'loaf_pans': ['loaf pans'],
#  'confectioners_sugar_orange': ['confectioners sugar orange'],
#  'orange_peel': ['orange peel'],
#  'puff_settle': ['puff settle'],
#  'whipped_cream_makes_servings': ['whipped cream makes servings'],
#  'sprayed_pam': ['sprayed pam'],
#  'prior_serving': ['prior serving'],
#  'double_layer': ['double layer'],
#  'mandarin_juice': ['mandarin juice'],
#  'soft_peaks': ['soft peaks'],
#  'holds_soft_peaks': ['holds soft peaks'],
#  'gently_fold': ['gently fold'],
#  'whipping_cream': ['whipping cream'],
#  'rubber_spatula': ['rubber spatula'],
#  'sifted_powdered': ['sifted powdered'],
#  'garlic_powder': ['garlic powder'],
#  'thyme_marjoram': ['thyme marjoram'],
#  'pineapple_oranges': ['pineapple oranges'],
#  'oranges_grapes': ['oranges grapes'],
#  'whipped_cream_strawberry': ['whipped cream strawberry'],
#  'horseradish_mustard': ['horseradish mustard'],
#  'brisket_fat': ['brisket fat'],
#  'shallow_dish': ['shallow dish'],
#  'slice_grain': ['slice grain'],
#  'orange_juice': ['orange juice'],
#  'strawberries_bananas': ['strawberries bananas'],
#  'allow_flavors': ['allow flavors'],
#  'lime_sherbet': ['lime sherbet'],
#  'bacon_fat': ['bacon fat'],
#  'oven_preheating': ['oven preheating'],
#  'plastic_bag': ['plastic bag'],
#  'close_bag': ['close bag'],
#  'room_temperature_overnight': ['room temperature overnight'],
#  'overnight_refrigerator': ['overnight refrigerator'],
#  'baste_marinade': ['baste marinade'],
#  'minced_garlic': ['minced garlic'],
#  'green_chilies': ['green chilies'],
#  'diced_tomatoes': ['diced tomatoes'],
#  'refrigerator_weeks': ['refrigerator weeks'],
#  'sealed_tupperware': ['sealed tupperware'],
#  'yolk_mixture': ['yolk mixture'],
#  'comes_boil': ['comes boil'],
#  'whipped_cream_topping': ['whipped cream topping'],
#  'olive_oil': ['olive oil'],
#  'olive_oil_lemon_juice': ['olive oil lemon juice'],
#  'blue_cheese': ['blue cheese'],
#  'spring_form': ['spring form'],
#  'spring_form_pan': ['spring form pan'],
#  'graham_cracker_crumbs': ['graham cracker crumbs'],
#  'ingredients_ginger_ale': ['ingredients ginger ale'],
#  'ice_cubes': ['ice cubes'],
#  'stir_ginger_ale': ['stir ginger ale'],
#  'crescent_rolls': ['crescent rolls'],
#  'kids_love': ['kids love'],
#  'dinner_plate': ['dinner plate'],
#  'bigger_diameter': ['bigger diameter'],
#  'home_dinner': ['home dinner'],
#  'smoked_sausage': ['smoked sausage'],
#  'piping_hot': ['piping hot'],
#  'following_recipe': ['following recipe'],
#  'special_occasions': ['special occasions'],
#  'cheese_melts': ['cheese melts'],
#  'goes_good': ['goes good'],
#  'whipped_topping': ['whipped topping'],
#  'powdered_sugar_spread': ['powdered sugar spread'],
#  'second_layer': ['second layer'],
#  'whipped_topping_pudding': ['whipped topping pudding'],
#  'fritos_doritos': ['fritos doritos'],
#  'tube_bundt': ['tube bundt'],
#  'cream_tartar': ['cream tartar'],
#  'flour_cream_tartar': ['flour cream tartar'],
#  'flour_disappears': ['flour disappears'],
#  'greased_casserole': ['greased casserole'],
#  'separate_rings': ['separate rings'],
#  'lightly_grease': ['lightly grease'],
#  'grease_loaf': ['grease loaf'],
#  'prevent_burning': ['prevent burning'],
#  'prevent_burning_sticking': ['prevent burning sticking'],
#  'repeat_layers': ['repeat layers'],
#  'yield_servings': ['yield servings'],
#  'preparation_time': ['preparation time'],
#  'quart_microwavable': ['quart microwavable'],
#  'minute_longer': ['minute longer'],
#  'sour_milk': ['sour milk'],
#  'accordance_directions': ['accordance directions'],
#  'simmer_uncovered': ['simmer uncovered'],
#  'yields_portions': ['yields portions'],
#  'pudding_directed': ['pudding directed'],
#  'powdered_sugar_vanilla': ['powdered sugar vanilla'],
#  'toothpick_comes': ['toothpick comes'],
#  'toothpick_comes_clean': ['toothpick comes clean'],
#  'preheat_oven_grease': ['preheat oven grease'],
#  'tomato_paste': ['tomato paste'],
#  'shallow_baking': ['shallow baking'],
#  'center_tortilla': ['center tortilla'],
#  'place_seam': ['place seam'],
#  'finely_chop': ['finely chop'],
#  'bell_pepper_add': ['bell pepper add'],
#  'diagonal_slices': ['diagonal slices'],
#  'onion_rings': ['onion rings'],
#  'boiling_point': ['boiling point'],
#  'chill_refrigerator': ['chill refrigerator'],
#  'egg_whites_stiff': ['egg whites stiff'],
#  'cream_shortening': ['cream shortening'],
#  'fold_egg_whites': ['fold egg whites'],
#  'alternate_layers': ['alternate layers'],
#  'according_directions_box': ['according directions box'],
#  'poke_holes': ['poke holes'],
#  'poke_holes_cake': ['poke holes cake'],
#  'crush_skor': ['crush skor'],
#  'pastry_blender': ['pastry blender'],
#  'coarse_meal': ['coarse meal'],
#  'yields_bars': ['yields bars'],
#  'chop_stems': ['chop stems'],
#  'bread_crumbs': ['bread crumbs'],
#  'mushroom_stems': ['mushroom stems'],
#  'mushroom_caps': ['mushroom caps'],
#  'serve_immediately': ['serve immediately'],
#  'pieces_store_airtight': ['pieces store airtight'],
#  'thinly_slice': ['thinly slice'],
#  'high_heat': ['high heat'],
#  'wire_rack': ['wire rack'],
#  'wire_rack_cool': ['wire rack cool'],
#  'cut_wedges': ['cut wedges'],
#  'calories_serving': ['calories serving'],
#  'cookie_dough': ['cookie dough'],
#  'cutting_board': ['cutting board'],
#  'roll_ups': ['roll ups'],
#  'makes_roll_ups': ['makes roll ups'],
#  'gelatin_dissolves': ['gelatin dissolves'],
#  'coconut_pecans': ['coconut pecans'],
#  'marshmallow_cream': ['marshmallow cream'],
#  'wheat_rye': ['wheat rye'],
#  'american_swiss': ['american swiss'],
#  'swiss_cheddar': ['swiss cheddar'],
#  'lard_lard': ['lard lard'],
#  'kitchen_countertop': ['kitchen countertop'],
#  'iron_skillet': ['iron skillet'],
#  'dutch_oven_heat': ['dutch oven heat'],
#  'garlic_ginger': ['garlic ginger'],
#  'sesame_oil': ['sesame oil'],
#  'separate_strands': ['separate strands'],
#  'juice_concentrate': ['juice concentrate'],
#  'pie_filling': ['pie filling'],
#  'makes_loaves': ['makes loaves'],
#  'beaten_eggs': ['beaten eggs'],
#  'bubbles_appear': ['bubbles appear'],
#  'olive_oil_skillet': ['olive oil skillet'],
#  'cranberries_burst': ['cranberries burst'],
#  'uncooked_pie_shell': ['uncooked pie shell'],
#  'whip_dream': ['whip dream'],
#  'dream_whip': ['dream whip'],
#  'dream_whip_mixture': ['dream whip mixture'],
#  'fold_blueberries': ['fold blueberries'],
#  'whip_milnot': ['whip milnot'],
#  'graham_crackers': ['graham crackers'],
#  'stick_oleo': ['stick oleo'],
#  'holds_peaks': ['holds peaks'],
#  'unbaked_pie_shells': ['unbaked pie shells'],
#  'crumb_mixture': ['crumb mixture'],
#  'peanut_butter_marshmallow': ['peanut butter marshmallow'],
#  'bars_makes_dozen': ['bars makes dozen'],
#  'confectioners_sugar_roll': ['confectioners sugar roll'],
#  'block_paraffin': ['block paraffin'],
#  'baker_s': ['baker s'],
#  'semi_sweet': ['semi sweet'],
#  'baker_s_semi_sweet': ['baker s semi sweet'],
#  'semi_sweet_chocolate': ['semi sweet chocolate'],
#  'bacon_bits': ['bacon bits'],
#  'corn_syrup': ['corn syrup'],
#  'confectioners_sugar_blended': ['confectioners sugar blended'],
#  'retain_shape': ['retain shape'],
#  'drop_teaspoonfuls': ['drop teaspoonfuls'],
#  'thickened_stirring_constantly': ['thickened stirring constantly'],
#  'sugar_dissolves': ['sugar dissolves'],
#  'thoroughly_heated': ['thoroughly heated'],
#  'canned_beets': ['canned beets'],
#  'work_better': ['work better'],
#  'chopped_walnuts': ['chopped walnuts'],
#  'turning_frequently': ['turning frequently'],
#  'cayenne_pepper': ['cayenne pepper'],
#  'yolks_whites': ['yolks whites'],
#  'banana_slices': ['banana slices'],
#  'bake_degree': ['bake degree'],
#  'degree_oven': ['degree oven'],
#  'crushed_corn': ['crushed corn'],
#  'freezer_freeze': ['freezer freeze'],
#  'directed_box': ['directed box'],
#  'grease_muffin': ['grease muffin'],
#  'right_serving': ['right serving'],
#  'egg_yolk': ['egg yolk'],
#  'slowly_steadily': ['slowly steadily'],
#  'store_fridge': ['store fridge'],
#  'fry_hamburg': ['fry hamburg'],
#  'hamburg_onion': ['hamburg onion'],
#  'nonstick_skillet': ['nonstick skillet'],
#  'medium_high': ['medium high'],
#  'shape_meatballs': ['shape meatballs'],
#  'dissolve_bouillon': ['dissolve bouillon'],
#  'cover_tightly': ['cover tightly'],
#  'crock_pot_add': ['crock pot add'],
#  'lowest_setting': ['lowest setting'],
#  'smooth_stirred': ['smooth stirred'],
#  'halfway_heating': ['halfway heating'],
#  'pineapple_chunks': ['pineapple chunks'],
#  'maraschino_cherries': ['maraschino cherries'],
#  'water_chestnuts': ['water chestnuts'],
#  'sweet_n': ['sweet n'],
#  'n_sour': ['n sour'],
#  'margarine_crisco': ['margarine crisco'],
#  'sour_cream_vanilla': ['sour cream vanilla'],
#  'ahead_refrigerated': ['ahead refrigerated'],
#  'sliced_peaches': ['sliced peaches'],
#  'tester_comes': ['tester comes'],
#  'whipped_cream_ice': ['whipped cream ice'],
#  'french_fried': ['french fried'],
#  'french_fried_onions': ['french fried onions'],
#  'grill_broil': ['grill broil'],
#  'longer_pink': ['longer pink'],
#  'turning_twice': ['turning twice'],
#  'low_speed': ['low speed'],
#  'wrap_foil': ['wrap foil'],
#  'crumbly_press': ['crumbly press'],
#  'sweet_potatoes': ['sweet potatoes'],
#  'discarding_stem': ['discarding stem'],
#  'saut_onion': ['saut onion'],
#  'prevent_lumping': ['prevent lumping'],
#  'rolled_toughening': ['rolled toughening'],
#  'handle_rolled_toughening': ['handle rolled toughening'],
#  'ball_forms': ['ball forms'],
#  'size_walnut': ['size walnut'],
#  'greased_bundt': ['greased bundt'],
#  'tightly_foil': ['tightly foil'],
#  'counter_overnight_morning': ['counter overnight morning'],
#  'invert_serving': ['invert serving'],
#  'makes_quarts': ['makes quarts'],
#  'scald_milk': ['scald milk'],
#  'glass_measuring': ['glass measuring'],
#  'power_minute': ['power minute'],
#  'chocolate_melts': ['chocolate melts'],
#  'melted_chocolate': ['melted chocolate'],
#  'allowing_excess': ['allowing excess'],
#  'allowing_excess_drip': ['allowing excess drip'],
#  'waxed_paper_lined': ['waxed paper lined'],
#  'blend_flavors': ['blend flavors'],
#  'fitting_lid': ['fitting lid'],
#  'jello_boiling': ['jello boiling'],
#  'deep_fry': ['deep fry'],
#  'peanut_butter_chips': ['peanut butter chips'],
#  'nuts_dates': ['nuts dates'],
#  'confectioners_sugar_cream': ['confectioners sugar cream'],
#  'bowl_food_processor': ['bowl food processor'],
#  'fitted_metal': ['fitted metal'],
#  'food_processor_fitted_metal': ['food processor fitted metal'],
#  'blade_process': ['blade process'],
#  'fitted_metal_blade_process': ['fitted metal blade process'],
#  'fine_crumbs': ['fine crumbs'],
#  'motor_running': ['motor running'],
#  'motor_running_add': ['motor running add'],
#  'makes_single': ['makes single'],
#  'single_crust': ['single crust'],
#  'liquid_evaporated': ['liquid evaporated'],
#  'chicken_longer_pink': ['chicken longer pink'],
#  'shredded_cabbage': ['shredded cabbage'],
#  'nonstick_frypan': ['nonstick frypan'],
#  'double_bulk': ['double bulk'],
#  'let_rise_double_bulk': ['let rise double bulk'],
#  'grease_square': ['grease square'],
#  'resembles_fine': ['resembles fine'],
#  'resembles_fine_meal': ['resembles fine meal'],
#  'powdered_sugar_cool': ['powdered sugar cool'],
#  'corned_beef_sprinkle': ['corned beef sprinkle'],
#  'caraway_seed': ['caraway seed'],
#  'rye_bread': ['rye bread'],
#  'cheez_whiz': ['cheez whiz'],
#  'sour_cream_cheez_whiz': ['sour cream cheez whiz'],
#  'red_pepper': ['red pepper'],
#  'waxed_paper_foil': ['waxed paper foil'],
#  'saving_liquid': ['saving liquid'],
#  'depending_weather': ['depending weather'],
#  'prick_fork': ['prick fork'],
#  'form_patties': ['form patties'],
#  'waxed_paper_gently': ['waxed paper gently'],
#  'golden_crisp': ['golden crisp'],
#  'canning_jars': ['canning jars'],
#  'leaving_headspace': ['leaving headspace'],
#  'canning_jars_leaving_headspace': ['canning jars leaving headspace'],
#  'water_bath': ['water bath'],
#  'men_love': ['men love'],
#  'mix_order_given': ['mix order given'],
#  'time_beating_addition': ['time beating addition'],
#  'crushed_wafers': ['crushed wafers'],
#  'pecan_halves': ['pecan halves'],
#  'leaving_shell': ['leaving shell'],
#  'catsup_mustard': ['catsup mustard'],
#  'coconut_pecan': ['coconut pecan'],
#  'open_door': ['open door'],
#  'sour_cream_parsley': ['sour cream parsley'],
#  'iron_skillets': ['iron skillets'],
#  'night_day': ['night day'],
#  'dough_sticky': ['dough sticky'],
#  'divide_dough': ['divide dough'],
#  'pie_shaped': ['pie shaped'],
#  'shaped_wedges': ['shaped wedges'],
#  'wide_end': ['wide end'],
#  'drain_excess': ['drain excess'],
#  'excess_liquid': ['excess liquid'],
#  'undrained_tomatoes': ['undrained tomatoes'],
#  'undrained_tomatoes_uncooked': ['undrained tomatoes uncooked'],
#  'uncooked_rice': ['uncooked rice'],
#  'chopped_chives': ['chopped chives'],
#  'simmer_stirring_occasionally': ['simmer stirring occasionally'],
#  'cabbage_leaves': ['cabbage leaves'],
#  'cabbage_rolls': ['cabbage rolls'],
#  'blender_blend': ['blender blend'],
#  'zucchini_coins': ['zucchini coins'],
#  'soak_cucumbers': ['soak cucumbers'],
#  'soak_overnight': ['soak overnight'],
#  'soak_alum': ['soak alum'],
#  'cucumbers_let_stand': ['cucumbers let stand'],
#  'spices_tied': ['spices tied'],
#  'covered_container': ['covered container'],
#  'box_directs': ['box directs'],
#  'crack_open': ['crack open'],
#  'coca_cola': ['coca cola'],
#  'coca_cola_icing': ['coca cola icing'],
#  'test_toothpick': ['test toothpick'],
#  'high_altitude': ['high altitude'],
#  'chilled_ginger_ale': ['chilled ginger ale'],
#  'near_center': ['near center'],
#  'comes_clean': ['comes clean'],
#  'near_center_comes_clean': ['near center comes clean'],
#  'catsup_worcestershire': ['catsup worcestershire'],
#  'crock_pot_low': ['crock pot low'],
#  'tightly_covered': ['tightly covered'],
#  'boiling_stirring_constantly': ['boiling stirring constantly'],
#  'ham_bone': ['ham bone'],
#  'meat_bone': ['meat bone'],
#  'prepared_day_ahead': ['prepared day ahead'],
#  'wax_paper_melt': ['wax paper melt'],
#  'paraffin_wax': ['paraffin wax'],
#  'paraffin_wax_dip': ['paraffin wax dip'],
#  'sunflower_seeds': ['sunflower seeds'],
#  'sunflower_seeds_raisins': ['sunflower seeds raisins'],
#  'depending_preference': ['depending preference'],
#  'plastic_container': ['plastic container'],
#  'shake_vigorously': ['shake vigorously'],
#  'cut_quarters': ['cut quarters'],
#  'electric_blender': ['electric blender'],
#  'order_achieve': ['order achieve'],
#  'mazola_oil': ['mazola oil'],
#  'blending_addition': ['blending addition'],
#  'pineapple_juice': ['pineapple juice'],
#  'orange_jello': ['orange jello'],
#  'cottage_cheese_mayonnaise': ['cottage cheese mayonnaise'],
#  'whipped_cream_pour': ['whipped cream pour'],
#  'preheat_oven_line': ['preheat oven line'],
#  'parchment_paper': ['parchment paper'],
#  'cookie_sheets_parchment_paper': ['cookie sheets parchment paper'],
#  'rounded_teaspoonfuls': ['rounded teaspoonfuls'],
#  'apart_prepared': ['apart prepared'],
#  'test_doneness': ['test doneness'],
#  'order_listed': ['order listed'],
#  'ingredients_order_listed': ['ingredients order listed'],
#  'salad_dressing': ['salad dressing'],
#  'cherry_juice': ['cherry juice'],
#  'red_food_coloring': ['red food coloring'],
#  'corn_tortillas': ['corn tortillas'],
#  'pieces_set_aside': ['pieces set aside'],
#  'warm_room_temperature': ['warm room temperature'],
#  'rub_fingers': ['rub fingers'],
#  'pale_golden': ['pale golden'],
#  'pale_golden_color': ['pale golden color'],
#  'wire_rack_store_airtight': ['wire rack store airtight'],
#  'celery_seed': ['celery seed'],
#  'garlic_clove': ['garlic clove'],
#  'lack_tartness': ['lack tartness'],
#  'apples_lack_tartness': ['apples lack tartness'],
#  'sliced_apples': ['sliced apples'],
#  'pastry_lined': ['pastry lined'],
#  'dot_butter': ['dot butter'],
#  'cut_slits': ['cut slits'],
#  'slits_crust': ['slits crust'],
#  'escape_steam': ['escape steam'],
#  'seal_flute': ['seal flute'],
#  'filling_seal_flute': ['filling seal flute'],
#  'alternately_creamed': ['alternately creamed'],
#  'incorporate_air': ['incorporate air'],
#  'lighten_texture': ['lighten texture'],
#  'lightly_floured': ['lightly floured'],
#  'lightly_floured_surface': ['lightly floured surface'],
#  'surface_roll': ['surface roll'],
#  'assorted_cookie_cutters': ['assorted cookie cutters'],
#  'decorate_colored': ['decorate colored'],
#  'flavor_crisco': ['flavor crisco'],
#  'electric_mixer_blended': ['electric mixer blended'],
#  'vanilla_almond_extract': ['vanilla almond extract'],
#  'desired_shapes': ['desired shapes'],
#  'cooling_rack': ['cooling rack'],
#  'cooling_rack_makes_dozen': ['cooling rack makes dozen'],
#  'makes_dozen_cookies': ['makes dozen cookies'],
#  'lemon_extract': ['lemon extract'],
#  'continue_beating': ['continue beating'],
#  'maybe_little': ['maybe little'],
#  'season_taste': ['season taste'],
#  'shredded_cheddar': ['shredded cheddar'],
#  'nacho_chips': ['nacho chips'],
#  'great_parties': ['great parties'],
#  'powdered_sugar_icing': ['powdered sugar icing'],
#  'dream_whip_milk': ['dream whip milk'],
#  'corn_meal': ['corn meal'],
#  'bouillon_cube': ['bouillon cube'],
#  'electric_mixer_medium': ['electric mixer medium'],
#  'peanut_butter_oleo': ['peanut butter oleo'],
#  'makes_servings_calories': ['makes servings calories'],
#  'fold_whipped_topping': ['fold whipped topping'],
#  'choco_bake': ['choco bake'],
#  'confectioners_sugar_milk': ['confectioners sugar milk'],
#  'beating_addition': ['beating addition'],
#  'kool_aid': ['kool aid'],
#  'kool_aid_jell': ['kool aid jell'],
#  'lemonade_pineapple': ['lemonade pineapple'],
#  'freeze_thaw': ['freeze thaw'],
#  'cutting_fit': ['cutting fit'],
#  'jelly_roll': ['jelly roll'],
#  'jelly_roll_fashion': ['jelly roll fashion'],
#  'chocolate_tchips': ['chocolate tchips'],
#  'butterscotch_chips': ['butterscotch chips'],
#  'drop_teaspoonful': ['drop teaspoonful'],
#  'picante_sauce': ['picante sauce'],
#  'thicken_cornstarch': ['thicken cornstarch'],
#  'crescent_rolls_flat': ['crescent rolls flat'],
#  'finely_chopped': ['finely chopped'],
#  'spreading_evenly': ['spreading evenly'],
#  'best_day_ahead': ['best day ahead'],
#  'toast_bread': ['toast bread'],
#  'log_cabin': ['log cabin'],
#  'electric_mixer_light_fluffy': ['electric mixer light fluffy'],
#  'best_results': ['best results'],
#  'glass_measure': ['glass measure'],
#  'safflower_oil': ['safflower oil'],
#  'chilled_room_temperature': ['chilled room temperature'],
#  'cukes_jar': ['cukes jar'],
#  'bell_peppers_jalapeno': ['bell peppers jalapeno'],
#  'stewed_tomatoes': ['stewed tomatoes'],
#  'wax_paper_makes_dozen': ['wax paper makes dozen'],
#  'follow_directions': ['follow directions'],
#  'upright_position': ['upright position'],
#  'casserole_dish_tater_tots': ['casserole dish tater tots'],
#  'tater_tots_bake': ['tater tots bake'],
#  'cast_iron': ['cast iron'],
#  'cast_iron_skillet': ['cast iron skillet'],
#  'reserving_drippings': ['reserving drippings'],
#  'ingredients_moistened': ['ingredients moistened'],
#  'rice_krispies': ['rice krispies'],
#  'measure_rice_krispies': ['measure rice krispies'],
#  ...}

# %% [markdown]
# - define function for replacing the individual words in the instruction text with the n-grams

# %%
ngram_replacer = KeywordProcessor()
ngram_replacer.add_keywords_from_dict(ngram_dict)

def replace_ngrams(text):
    text = ngram_replacer.replace_keywords(text)
    return text

# %% [markdown]
# - apply replace function to the training data

# %%
# %%time
dataset_pp['instructions_pp_ngrams'] = dataset_pp['instructions_pp'].apply(replace_ngrams)
# Out:
# CPU times: user 5min 31s, sys: 7.18 s, total: 5min 38s
# Wall time: 5min 47s
# <timed exec>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# - drop not replaced column

# %%
training_data = dataset_pp.drop(['instructions_pp'], axis=1)

# %%
training_data
# Out:
#                                    instructions_pp_ngrams
# 0       heavy quart_saucepan mix brown sugar nuts evap...
# 1       place chipped_beef baking_dish place chicken b...
# 2       slow_cooker combine ingredients cover cook low...
# 3       boil debone_chicken bite_size_pieces average_s...
# 4       combine ingredients press ungreased pan melt_c...
# ...                                                   ...
# 522511  beat_eggs add oil water pumpkin mix add baking...
# 522512  preheat_oven_deg grease cake pan recipe_uses m...
# 522513  position_rack_center oven preheat  place beef ...
# 522514  heat half half heavy_cream simmer add sugar re...
# 522516  mix sausage panko egg_yolk wocestershire sauce...
#
# [2353441 rows x 1 columns]

# %% [markdown]
# - save the final training data as pickle file for training the word2vec model

# %%
training_data.to_pickle('SRM_training_data.pkl')

# %% [markdown]
# ## 2.0 Ingredient List

# %% [markdown]
# ### 2.1 Build Ingredient List

# %% [markdown]
# The ingredient list for filtering the final substitute results is retrieved from the NER column of the RecipeNLG Dataset (data_RecipeNLG):

# %%
ingredients_data = [data_RecipeNLG["NER"]]

pd.set_option("display.max_colwidth", 100)
ingredients_data = pd.concat(ingredients_data, axis=1) 
ingredients_data
# Out:
#                                                                                                          NER
# 0                   ["brown sugar", "milk", "vanilla", "nuts", "butter", "bite size shredded rice biscuits"]
# 1                                        ["beef", "chicken breasts", "cream of mushroom soup", "sour cream"]
# 2                               ["frozen corn", "cream cheese", "butter", "garlic powder", "salt", "pepper"]
# 3                                  ["chicken", "chicken gravy", "cream of mushroom soup", "shredded cheese"]
# 4                  ["peanut butter", "graham cracker crumbs", "butter", "powdered sugar", "chocolate chips"]
# ...                                                                                                      ...
# 2231137                    ["chocolate hazelnut spread", "tortillas", "butter", "marshmallows", "hazelnuts"]
# 2231138                                      ["eggs", "paprika", "salt", "choice", "miracle whip", "relish"]
# 2231139                                  ["radish", "Sesame oil", "White sesame seeds", "Salt", "Soy sauce"]
# 2231140  ["apple cider", "sugar", "kosher salt", "bay leaves", "arbol", "berries", "caraway seeds", "must...
# 2231141  ["ground veal", "sausage", "bread crumbs", "milk", "garlic", "flat-leaf", "egg whites", "tomato ...
#
# [2231142 rows x 1 columns]

# %% [markdown]
# - check for missing values

# %%
ingredients_data['NER'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Build a list of every ingredient used in all recipes:
#
# - convert *string* values in the ingredients column to *arrays*

# %%
ingredients_data["ingredients"] = ingredients_data["NER"].apply(eval)

# %%
ingredients_data = ingredients_data.drop(['NER'], axis=1)
ingredients_data
# Out:
#                                                                                                  ingredients
# 0                               [brown sugar, milk, vanilla, nuts, butter, bite size shredded rice biscuits]
# 1                                                [beef, chicken breasts, cream of mushroom soup, sour cream]
# 2                                           [frozen corn, cream cheese, butter, garlic powder, salt, pepper]
# 3                                          [chicken, chicken gravy, cream of mushroom soup, shredded cheese]
# 4                            [peanut butter, graham cracker crumbs, butter, powdered sugar, chocolate chips]
# ...                                                                                                      ...
# 2231137                              [chocolate hazelnut spread, tortillas, butter, marshmallows, hazelnuts]
# 2231138                                                  [eggs, paprika, salt, choice, miracle whip, relish]
# 2231139                                            [radish, Sesame oil, White sesame seeds, Salt, Soy sauce]
# 2231140  [apple cider, sugar, kosher salt, bay leaves, arbol, berries, caraway seeds, mustard seeds, cori...
# 2231141  [ground veal, sausage, bread crumbs, milk, garlic, flat-leaf, egg whites, tomato paste, freshly ...
#
# [2231142 rows x 1 columns]

# %% [markdown]
# Examine the ingredient list:

# %%
ingredients_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2231142 entries, 0 to 2231141
# Data columns (total 1 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   ingredients  object
# dtypes: object(1)
# memory usage: 17.0+ MB

# %% [markdown]
# - list every ingredient used in each row, i.e., recipe, individually

# %%
def to_1D(series):
    return pd.Series([x for _list in series for x in _list])

# %%
ingredient_list_individual = to_1D(ingredients_data['ingredients'])
ingredient_list_individual
# Out:
# 0                                     brown sugar
# 1                                            milk
# 2                                         vanilla
# 3                                            nuts
# 4                                          butter
#                             ...
# 18921245                             tomato paste
# 18921246    freshly grated Pecorino Romano cheese
# 18921247                                     Salt
# 18921248                             tomato sauce
# 18921249                               red pepper
# Length: 18921250, dtype: object

# %%
total_ingredient_list = pd.DataFrame(ingredient_list_individual, columns = ['ingredient'])
total_ingredient_list
# Out:
#                                      ingredient
# 0                                   brown sugar
# 1                                          milk
# 2                                       vanilla
# 3                                          nuts
# 4                                        butter
# ...                                         ...
# 18921245                           tomato paste
# 18921246  freshly grated Pecorino Romano cheese
# 18921247                                   Salt
# 18921248                           tomato sauce
# 18921249                             red pepper
#
# [18921250 rows x 1 columns]

# %% [markdown]
# ### 2.2 Data Preprocessing
#
# The following Chapter preprosses the ingredinet list. The preprocessing includes:
# 1.	Convert letters into lower case
# 2.	Remove punctuations and numerical digits
# 3.	Remove stopwords
# 4.	Remove symbols
# 5.	Handle missing values
# 6.	Extend ingredient list with frequency count
# 7.	Drop ingredients with frequency lower than five
# 8.	Count frequency of ingredients in training data
# 9.	Revise ingredient list manually

# %% [markdown]
# #### 2.2.1 Remove Stopwords
#
# - define individual stopwords

# %%
to_remove_ingredients = [
    'additional',
    'barilla',
    'best',
    'bite',
    'bites',
    'boiled',
    'bottled',
    'bought',
    'bowl',
    'bowls',
    'breakfast', 
    'c',
    'chopped',
    'chunk',
    'chunks',
    'cold',
    'cooked',
    'cooking',
    'cool',
    'creamy',
    'crusty',
    'cup',
    'cups',
    'dish',
    'drained',
    'f',  
    'favorite',
    'fine',
    'firm',
    'fresh',
    'freshly',
    'fried',
    'frozen',
    'fry',
    'fryer',
    'frying',
    'fully',
    'gluten',
    'gram',
    'grams',
    'half',
    'halves',
    'handful',
    'hard',
    'hardboiled',
    'health',
    'healthy',
    'home',
    'homemade',
    'hot',
    'inch',
    'inches',
    'kg',
    'kilogram',
    'kilograms',
    'large',
    'leaf',
    'leaves',
    'leftover',
    'leftovers',
    'lightly',
    'like',
    'low',
    'lunch',
    'measures',
    'measuring',
    'melting',
    'mg',
    'miligram',
    'miligrams',
    'mixing',
    'new',
    'non',
    'o',
    'optional',
    'original',
    'ounce',
    'ounces',
    'oz',
    'pack',
    'packed',
    'pan',
    'piece',
    'pieces',
    'pkg',
    'pound',
    'pounds',
    'premade',
    'prepared',
    'pwdr',
    'quality',
    'recipe',
    'ripe',
    'shelled',
    'short',
    'size',
    'sized',
    'slice',
    'sliced',
    'slices',
    'small',
    'soft',
    'spray',
    'steamed',
    'stir',
    'store',
    'strong',
    'style',
    'substitute',
    'substitutes',
    't',
    'tablespoon',
    'tablespoons',
    'tasting',
    'tblsp',
    'tbs',
    'tbsp',
    'tbspful',
    'tbspn',
    'tbspoon',
    'tbsps',
    'teaspoon',
    'teaspoons',
    'tightly',
    'torn',
    'tsp',
    'tsps',
    'ub',
    'unbleached',
    'uncooked',
    'vital',
    'warm',
    'washed',
    'weight',
    'whisk',
    'x'
]

# %%
ingredients_stopwords = STOPWORDS.union(set(to_remove_ingredients))

# %% [markdown]
# - define function for stopword removal

# %%
def remove_ingredients_stopwords(s):
    s = utils.to_unicode(s)
    return " ".join(w for w in s.split() if w not in ingredients_stopwords)

# %% [markdown]
# #### 2.2.2 Preprocessing Function

# %%
def preprocess_ingredients(text):
    text = text.lower()
    text = pp.strip_punctuation(text)
    text = pp.strip_numeric(text)
    text = remove_ingredients_stopwords(text)
    text = remove_symbols(text)
  
    return text

# %% [markdown]
# - apply preprocessing function to the ingredient list

# %%
# %%time
total_ingredient_list['ingredient_pp'] = total_ingredient_list.ingredient.apply(preprocess_ingredients)
total_ingredient_list
# Out:
# CPU times: user 2min 12s, sys: 1.84 s, total: 2min 14s
# Wall time: 2min 15s
#                                      ingredient                  ingredient_pp
# 0                                   brown sugar                    brown sugar
# 1                                          milk                           milk
# 2                                       vanilla                        vanilla
# 3                                          nuts                           nuts
# 4                                        butter                         butter
# ...                                         ...                            ...
# 18921245                           tomato paste                   tomato paste
# 18921246  freshly grated Pecorino Romano cheese  grated pecorino romano cheese
# 18921247                                   Salt                           salt
# 18921248                           tomato sauce                   tomato sauce
# 18921249                             red pepper                     red pepper
#
# [18921250 rows x 2 columns]

# %% [markdown]
# - drop not preprocessed column

# %%
ingredient_list_pp = total_ingredient_list.drop(['ingredient'], axis=1)
ingredient_list_pp
# Out:
#                           ingredient_pp
# 0                           brown sugar
# 1                                  milk
# 2                               vanilla
# 3                                  nuts
# 4                                butter
# ...                                 ...
# 18921245                   tomato paste
# 18921246  grated pecorino romano cheese
# 18921247                           salt
# 18921248                   tomato sauce
# 18921249                     red pepper
#
# [18921250 rows x 1 columns]

# %% [markdown]
# #### 2.2.3 Missing Values
#
# - replace empty values with NaN

# %%
ingredient_list_pp['ingredient_pp'].replace('', np.nan, inplace=True)

# %%
ingredient_list_pp['ingredient_pp'].isnull().sum()
# Out:
# 116565

# %% [markdown]
# - drop empty rows

# %%
ingredient_list_pp.dropna(subset = ["ingredient_pp"], inplace=True)

# %%
ingredient_list_pp = ingredient_list_pp[ingredient_list_pp['ingredient_pp'].notnull()]

# %%
ingredient_list_pp
# Out:
#                           ingredient_pp
# 0                           brown sugar
# 1                                  milk
# 2                               vanilla
# 3                                  nuts
# 4                                butter
# ...                                 ...
# 18921245                   tomato paste
# 18921246  grated pecorino romano cheese
# 18921247                           salt
# 18921248                   tomato sauce
# 18921249                     red pepper
#
# [18804685 rows x 1 columns]

# %% [markdown]
# #### 2.2.4 Extend ingredient list with frequency count
#
# - count frequency of ingredient in ingredient list

# %%
ingredient_list_pp = (ingredient_list_pp['ingredient_pp']).value_counts()
ingredient_list_pp
# Out:
# salt                   1015689
# sugar                   666053
# butter                  545664
# flour                   489085
# eggs                    422622
#                         ...
# malagkit                     1
# extra ginger                 1
# brown organic eggs           1
# danya                        1
# white string cheese          1
# Name: ingredient_pp, Length: 154844, dtype: int64

# %%
ingredient_frequency_list = pd.DataFrame({'ingredient':ingredient_list_pp.index, 'frequency':ingredient_list_pp.values})
ingredient_frequency_list.index = np.arange(1, (len(ingredient_list_pp) + 1))
ingredient_frequency_list
# Out:
#                  ingredient  frequency
# 1                      salt    1015689
# 2                     sugar     666053
# 3                    butter     545664
# 4                     flour     489085
# 5                      eggs     422622
# ...                     ...        ...
# 154840             malagkit          1
# 154841         extra ginger          1
# 154842   brown organic eggs          1
# 154843                danya          1
# 154844  white string cheese          1
#
# [154844 rows x 2 columns]

# %% [markdown]
# - check for missing values

# %%
ingredient_frequency_list['ingredient'].replace('', np.nan, inplace=True)

# %%
ingredient_frequency_list['ingredient'].isnull().sum()
# Out:
# 0

# %% [markdown]
# - drop ingredients with frequency lower than five

# %%
ingredient_frequency_list.drop(ingredient_frequency_list.loc[ingredient_frequency_list["frequency"] < 5].index, inplace=True)

# %%
ingredient_frequency_list
# Out:
#                       ingredient  frequency
# 1                           salt    1015689
# 2                          sugar     666053
# 3                         butter     545664
# 4                          flour     489085
# 5                           eggs     422622
# ...                          ...        ...
# 27197  cheesy scalloped potatoes          5
# 27198                        bug          5
# 27199              venison chops          5
# 27200      international italian          5
# 27201           skinless halibut          5
#
# [27201 rows x 2 columns]

# %% [markdown]
# #### 2.2.5 Count frequency of ingredients in training data

# %% [markdown]
# - transform DataFrame into list and replace blank space with underscore

# %%
ingredient_list = ingredient_frequency_list["ingredient"].to_list()

# %%
ingredient_list
# Out:
# ['salt',
#  'sugar',
#  'butter',
#  'flour',
#  'eggs',
#  'onion',
#  'garlic',
#  'water',
#  'milk',
#  'vanilla',
#  'olive oil',
#  'pepper',
#  'brown sugar',
#  'egg',
#  'tomatoes',
#  'baking powder',
#  'lemon juice',
#  'cinnamon',
#  'parsley',
#  'cream cheese',
#  'sour cream',
#  'baking soda',
#  'celery',
#  'chicken',
#  'margarine',
#  'cheddar cheese',
#  'oil',
#  'vegetable oil',
#  'onions',
#  'mayonnaise',
#  'parmesan cheese',
#  'pecans',
#  'potatoes',
#  'kosher salt',
#  'ground black pepper',
#  'basil',
#  'carrots',
#  'nuts',
#  'soy sauce',
#  'black pepper',
#  'pineapple',
#  'thyme',
#  'oregano',
#  'honey',
#  'bacon',
#  'mushrooms',
#  'unsalted butter',
#  'chicken broth',
#  'extra virgin olive oil',
#  'mustard',
#  'ground beef',
#  'cilantro',
#  'worcestershire sauce',
#  'cornstarch',
#  'paprika',
#  'red pepper',
#  'ginger',
#  'powdered sugar',
#  'green pepper',
#  'vinegar',
#  'lemon',
#  'green onions',
#  'nutmeg',
#  'ground cinnamon',
#  'rice',
#  'shortening',
#  'walnuts',
#  'chicken breasts',
#  'heavy cream',
#  'buttermilk',
#  'chili powder',
#  'cheese',
#  'raisins',
#  'clove garlic',
#  'bay',
#  'cocoa',
#  'red onion',
#  'bread',
#  'orange juice',
#  'purpose',
#  'white sugar',
#  'soda',
#  'tomato sauce',
#  'white wine',
#  'mozzarella cheese',
#  'coconut',
#  'chocolate chips',
#  'zucchini',
#  'lime juice',
#  'peanut butter',
#  'shrimp',
#  'cayenne pepper',
#  'carrot',
#  'bread crumbs',
#  'ground cumin',
#  'cream mushroom soup',
#  'boiling water',
#  'strawberries',
#  'cream',
#  'apples',
#  'tomato',
#  'egg yolks',
#  'bananas',
#  'egg whites',
#  'almonds',
#  'broccoli',
#  'corn',
#  'cream chicken soup',
#  'canola oil',
#  'rosemary',
#  'chocolate',
#  'tomato paste',
#  'spinach',
#  'ketchup',
#  'mint',
#  'ground pepper',
#  'oleo',
#  'chives',
#  'yeast',
#  'green onion',
#  'red bell pepper',
#  'cumin',
#  'marshmallows',
#  'scallions',
#  'cloves',
#  'peas',
#  'sauce',
#  'whipping cream',
#  'sausage',
#  'red wine vinegar',
#  'ham',
#  'sesame oil',
#  'ground ginger',
#  'green beans',
#  'cabbage',
#  'beans',
#  'garlic powder',
#  'ground nutmeg',
#  'shallots',
#  'cucumber',
#  'lime',
#  'balsamic vinegar',
#  'dill',
#  'oats',
#  'condensed milk',
#  'cranberries',
#  'garlic salt',
#  'breadcrumbs',
#  'maple syrup',
#  'bell pepper',
#  'blueberries',
#  'orange',
#  'hamburger',
#  'peanuts',
#  'lemon zest',
#  'sage',
#  'chicken stock',
#  'white vinegar',
#  'beef',
#  'green bell pepper',
#  'curry powder',
#  'stalks celery',
#  'crackers',
#  'wheat flour',
#  'light brown sugar',
#  'olives',
#  'onion powder',
#  'pasta',
#  'ground cloves',
#  'black beans',
#  'swiss cheese',
#  'cider vinegar',
#  'black olives',
#  'molasses',
#  'salsa',
#  'red wine',
#  'avocado',
#  'pineapple juice',
#  'cottage cheese',
#  'apple',
#  'peaches',
#  'pumpkin',
#  'noodles',
#  'green chilies',
#  'dry mustard',
#  'yogurt',
#  'shallot',
#  'grated cheese',
#  'yellow onion',
#  'confectioners sugar',
#  'allspice',
#  'dates',
#  'sesame seeds',
#  'cream tartar',
#  'lemons',
#  'peppers',
#  'white pepper',
#  'banana',
#  'salmon',
#  'pork',
#  'catsup',
#  'flour tortillas',
#  'feta cheese',
#  'beef broth',
#  'green peppers',
#  'kidney beans',
#  'salad oil',
#  'tomato soup',
#  'italian seasoning',
#  'vanilla extract',
#  'cornmeal',
#  'semi sweet chocolate chips',
#  'velveeta cheese',
#  'sherry',
#  'graham cracker crumbs',
#  'ricotta cheese',
#  'oranges',
#  'sweet potatoes',
#  'egg yolk',
#  'capers',
#  'cauliflower',
#  'onion soup',
#  'granulated sugar',
#  'cucumbers',
#  'turmeric',
#  'raspberries',
#  'tarragon',
#  'light corn syrup',
#  'horseradish',
#  'white wine vinegar',
#  'tabasco sauce',
#  'water chestnuts',
#  'lean ground beef',
#  'topping',
#  'apple cider vinegar',
#  'kernel corn',
#  'orange zest',
#  'vanilla ice cream',
#  'coconut milk',
#  'filling',
#  'rice vinegar',
#  'coriander',
#  'barbecue sauce',
#  'active dry yeast',
#  'crust',
#  'dressing',
#  'cake',
#  'tuna',
#  'pastry',
#  'macaroni',
#  'coffee',
#  'heavy whipping cream',
#  'chicken breast',
#  'parsley flakes',
#  'rolled oats',
#  'ground coriander',
#  'turkey',
#  'oatmeal',
#  'cayenne',
#  'cake flour',
#  'almond',
#  'pork chops',
#  'white onion',
#  'crisco',
#  'cream celery soup',
#  'fish sauce',
#  'parmesan',
#  'mushroom soup',
#  'peanut oil',
#  'cherry pie filling',
#  'mango',
#  'red',
#  'whipped cream',
#  'red potatoes',
#  'mandarin oranges',
#  'syrup',
#  'pecan',
#  'corn tortillas',
#  'corn syrup',
#  'egg noodles',
#  'american cheese',
#  'chili sauce',
#  'italian dressing',
#  'white bread',
#  'brandy',
#  'maraschino cherries',
#  'tomato juice',
#  'dill weed',
#  'avocados',
#  'condensed cream',
#  'red peppers',
#  'ground allspice',
#  'cherries',
#  'applesauce',
#  'shell',
#  'sweet onion',
#  'bisquick',
#  'potato',
#  'apple juice',
#  'shredded cheese',
#  'taco',
#  'vegetable broth',
#  'goat cheese',
#  'chickpeas',
#  'eggplant',
#  'baby spinach',
#  'rum',
#  'almond extract',
#  'leeks',
#  'flat parsley',
#  'vodka',
#  'flaked coconut',
#  'lemon rind',
#  'tortilla chips',
#  'pimento',
#  'marjoram',
#  'pinto beans',
#  'salad dressing',
#  'vegetable stock',
#  'cherry tomatoes',
#  'cocoa powder',
#  'vanilla pudding',
#  'ground pork',
#  'spaghetti sauce',
#  'ground turkey',
#  'mushroom',
#  'celery salt',
#  'bread flour',
#  'yellow cake',
#  'vegetables',
#  'arugula',
#  'white rice',
#  'buns',
#  'red onions',
#  'brown rice',
#  'pepperoni',
#  'yellow cake mix',
#  'red bell peppers',
#  'curry',
#  'crescent rolls',
#  'vanilla wafers',
#  'coconut oil',
#  'scallion',
#  'ground red pepper',
#  'plain yogurt',
#  'ginger ale',
#  'mozzarella',
#  'vegetable',
#  'hearts',
#  'elbow macaroni',
#  'italian parsley',
#  'gingerroot',
#  'blue cheese',
#  'green olives',
#  'italian sausage',
#  'long grain rice',
#  'skinless',
#  'broccoli florets',
#  'cashews',
#  'ground chuck',
#  'bell peppers',
#  'crabmeat',
#  'mixed vegetables',
#  'rhubarb',
#  'miracle',
#  'salad',
#  'unflavored gelatin',
#  'light cream',
#  'apple cider',
#  'black peppercorns',
#  'philadelphia cream cheese',
#  'vegetable shortening',
#  'graham crackers',
#  'cake mix',
#  'icing sugar',
#  'strawberry',
#  'lasagna noodles',
#  'vanilla bean',
#  'caster sugar',
#  'pepper sauce',
#  'cheddar',
#  'pumpkin pie spice',
#  'corn flakes',
#  'rice krispies',
#  'white chocolate',
#  'cranberry sauce',
#  'poultry seasoning',
#  'head lettuce',
#  'orange rind',
#  'bittersweet chocolate',
#  'pimentos',
#  'beer',
#  'cumin seeds',
#  'pine nuts',
#  'spaghetti',
#  'graham cracker crust',
#  'sauerkraut',
#  'butternut squash',
#  'bourbon',
#  'cracker crumbs',
#  'pork sausage',
#  'confectioners',
#  'sake',
#  'beef stock',
#  'baking potatoes',
#  'pie shell',
#  'bean sprouts',
#  'gelatin',
#  'yellow cornmeal',
#  'pork tenderloin',
#  'beets',
#  'golden raisins',
#  'liquid smoke',
#  'mirin',
#  'garam masala',
#  'romano cheese',
#  'sweet red pepper',
#  'sunflower seeds',
#  'tomato puree',
#  'green peas',
#  'corn kernels',
#  'green bell peppers',
#  'romaine lettuce',
#  'quinoa',
#  'lemon pepper',
#  'hazelnuts',
#  'baking',
#  'strawberry jello',
#  'mayo',
#  'yellow squash',
#  'ingredients',
#  'ground turmeric',
#  'cereal',
#  'onion salt',
#  'herbs',
#  'chocolate cake',
#  'squeezed lemon juice',
#  'asparagus',
#  'pizza sauce',
#  'pumpkin puree',
#  'dijon mustard',
#  'ground cardamom',
#  'rice wine vinegar',
#  'crab meat',
#  'yellow onions',
#  'fruit',
#  'couscous',
#  'hoisin sauce',
#  'chocolate syrup',
#  'blackberries',
#  'mix',
#  'vanilla instant pudding',
#  'green chiles',
#  'wesson oil',
#  'rolls',
#  'jalapenos',
#  'coloring',
#  'pistachios',
#  'provolone cheese',
#  'cinnamon sticks',
#  'lemonade',
#  'radishes',
#  'oyster sauce',
#  'lime zest',
#  'cracked black pepper',
#  'corn oil',
#  'shredded monterey jack cheese',
#  'shiitake mushrooms',
#  'frosting',
#  'yellow bell pepper',
#  'greek yogurt',
#  'linguine',
#  'lard',
#  'yellow mustard',
#  'white flour',
#  'butterscotch chips',
#  'pretzels',
#  'whipped topping',
#  'shredded lettuce',
#  'fruit cocktail',
#  'fennel',
#  'egg white',
#  'lemon peel',
#  'pie crust',
#  'fat',
#  'garbanzo beans',
#  'cream corn',
#  'red kidney beans',
#  'unsweetened applesauce',
#  'lemon wedges',
#  'berries',
#  'italian salad dressing',
#  'cranberry juice',
#  'cookies',
#  'grape tomatoes',
#  'ground white pepper',
#  'poppy seed',
#  'dark rum',
#  'okra',
#  'bran',
#  'caramels',
#  'purpose flour',
#  'lettuce',
#  'potato chips',
#  'apricot',
#  'sweet milk',
#  'chiles',
#  'jalapeno',
#  'celery stalks',
#  'sweet potato',
#  'apricots',
#  'tortillas',
#  'taco seasoning',
#  'jalapeno peppers',
#  'pimiento',
#  'coarse salt',
#  'cubes',
#  'head cabbage',
#  'croutons',
#  'milk chocolate',
#  'spring onions',
#  'currants',
#  'kale',
#  'orange marmalade',
#  'vanilla flavoring',
#  'corn meal',
#  's',
#  'fennel seeds',
#  'jalapeno pepper',
#  'chili',
#  'snow peas',
#  'tahini',
#  'sherry vinegar',
#  'ginger root',
#  'eggplants',
#  'peppercorns',
#  'picante sauce',
#  'grapes',
#  'semi sweet chocolate',
#  'coriander seeds',
#  'instant vanilla pudding',
#  'dough',
#  'apricot preserves',
#  'sharp cheese',
#  'ro tel tomatoes',
#  'onion soup mix',
#  'fish',
#  'bacon bits',
#  'white',
#  'ground meat',
#  'ground mustard',
#  'cajun seasoning',
#  'lamb',
#  'gruyere cheese',
#  'enchilada sauce',
#  'olive',
#  'meal',
#  'wine',
#  'baguette',
#  'pancetta',
#  'unsweetened cocoa',
#  'green',
#  'hash browns',
#  'sour milk',
#  'anchovy',
#  'lemon extract',
#  'clove',
#  'poppy seeds',
#  'tapioca',
#  'chicken thighs',
#  'green cabbage',
#  'button mushrooms',
#  'creme fraiche',
#  'mustard seeds',
#  'nonstick',
#  'worcestershire',
#  'sweet paprika',
#  'chili beans',
#  'red food coloring',
#  'penne pasta',
#  'tequila',
#  'white beans',
#  'baby carrots',
#  'club soda',
#  'taco sauce',
#  'red cabbage',
#  'oysters',
#  'onion flakes',
#  'accent',
#  'pear',
#  'marshmallow cream',
#  'unsweetened chocolate',
#  'basmati rice',
#  'wine vinegar',
#  'milk chocolate chips',
#  'center',
#  'pasta sauce',
#  'lemon jello',
#  'walnut',
#  'cannellini beans',
#  'marshmallow creme',
#  'chocolate pudding',
#  'anise',
#  'artichokes',
#  'mussels',
#  'white chocolate chips',
#  'italian bread',
#  'clams',
#  'mascarpone cheese',
#  'simple syrup',
#  'teriyaki sauce',
#  'meat',
#  'shredded coconut',
#  'chilies',
#  'slivered almonds',
#  'raspberry',
#  'germ',
#  'taco seasoning mix',
#  'marinade',
#  'saffron',
#  'russet potatoes',
#  'pork loin',
#  'ground almonds',
#  'cheddar cheese soup',
#  'chicken bouillon',
#  'baking cocoa',
#  'stuffing mix',
#  'marinara sauce',
#  'dream whip',
#  'black eyed peas',
#  'white cake',
#  'arborio rice',
#  'crunchy peanut butter',
#  'pork shoulder',
#  'turkey breast',
#  'prunes',
#  'caraway seeds',
#  'pumpkin seeds',
#  'oreo cookies',
#  'sunflower oil',
#  'white onions',
#  'liqueur',
#  'grated parmesan cheese',
#  'sherry wine',
#  'choice',
#  'muffins',
#  'peach',
#  'fat milk',
#  'parsnips',
#  'tofu',
#  'pastry shell',
#  'fennel bulb',
#  'barley',
#  'ricotta',
#  'lentils',
#  'regular',
#  'corn chips',
#  'orange juice concentrate',
#  'chili pepper',
#  'vanilla yogurt',
#  'mustard powder',
#  'chicken bouillon cubes',
#  'wheat bread',
#  'stock',
#  'flat',
#  'yellow pepper',
#  'peppermint',
#  'orange jello',
#  'wild rice',
#  'gin',
#  'broth',
#  'caraway seed',
#  'light mayonnaise',
#  'roma tomatoes',
#  'red chili pepper',
#  'long grain white rice',
#  'cognac',
#  'orange peel',
#  'green tomatoes',
#  'nonfat yogurt',
#  'pimientos',
#  'semisweet chocolate',
#  'chuck roast',
#  'cornflour',
#  'pet milk',
#  'candied cherries',
#  'mangoes',
#  'cantaloupe',
#  'gold potatoes',
#  'nonfat milk',
#  'biscuit mix',
#  'brussels',
#  'maple',
#  'lobster',
#  'crisco oil',
#  'squeezed lime juice',
#  'powdered milk',
#  'grapeseed oil',
#  'cornflakes',
#  'limes',
#  'flank steak',
#  'splenda sugar',
#  'bay seasoning',
#  'scallops',
#  'white corn syrup',
#  'butter beans',
#  'cherry',
#  'beef bouillon',
#  'dried basil',
#  'cardamom',
#  'salami',
#  'chile powder',
#  'chickens',
#  'lump crabmeat',
#  'black',
#  'brown mustard',
#  'grand marnier',
#  'lime wedges',
#  'clam juice',
#  'packet',
#  'kahlua',
#  'almond milk',
#  'tart apples',
#  'graham cracker pie crust',
#  'salad greens',
#  'crushed ice',
#  'polenta',
#  'wheat pastry flour',
#  'sesame seed',
#  'popcorn',
#  'splenda',
#  'grain mustard',
#  'ghee',
#  'brownie mix',
#  'steak sauce',
#  'feta',
#  'vinaigrette',
#  'corn muffin',
#  'salmon fillet',
#  'rice flour',
#  'red chilies',
#  'sweet',
#  'sweet onions',
#  'pineapple tidbits',
#  'pears',
#  'light sour cream',
#  'bitters',
#  'hash brown potatoes',
#  'watermelon',
#  'lime jello',
#  'espresso powder',
#  'chunky peanut butter',
#  'sprinkles',
#  'stuffing',
#  'roll',
#  'green chili peppers',
#  'instant coffee',
#  'white mushrooms',
#  'steak',
#  'ground lamb',
#  'nectar',
#  'biscuits',
#  'ready',
#  'food coloring',
#  'dark brown sugar',
#  'purple onion',
#  'ro tel',
#  'figs',
#  'ground cayenne pepper',
#  'layer',
#  'anchovies',
#  'red curry',
#  'ground chicken',
#  'generous',
#  'rice wine',
#  'kielbasa',
#  'tabasco',
#  'beef brisket',
#  'beef tenderloin',
#  'white karo syrup',
#  'pearl barley',
#  'red beans',
#  'cumin powder',
#  'seasoning',
#  'italian',
#  'toppings',
#  'chocolate cake mix',
#  'sweet basil',
#  'creole seasoning',
#  'chunky salsa',
#  'pesto sauce',
#  'white cake mix',
#  'ramen noodles',
#  'mace',
#  'pickles',
#  'sweet chili sauce',
#  'baby arugula',
#  'pesto',
#  'chili peppers',
#  'squash',
#  'smooth peanut butter',
#  'soymilk',
#  'cinnamon sugar',
#  'penne',
#  'blanched almonds',
#  'coffee granules',
#  'squeezed orange juice',
#  'whiskey',
#  'swiss chard',
#  'whip',
#  'vidalia onion',
#  'deli',
#  'corned beef',
#  'prawns',
#  'coconut flakes',
#  'cremini mushrooms',
#  'rice noodles',
#  'red chili powder',
#  'wonton wrappers',
#  'chili flakes',
#  'doritos',
#  'dill pickles',
#  'ranch dressing',
#  'fettuccine',
#  'tater',
#  'apple pie filling',
#  'fennel seed',
#  'ground round',
#  'cracked pepper',
#  'corn bread',
#  'stew meat',
#  'extra lean ground beef',
#  'dutch',
#  'beef stew meat',
#  'sweet pickle',
#  'velveeta',
#  'pasta shells',
#  'meatballs',
#  'preserves',
#  'veal',
#  'chia seeds',
#  'golden raisin',
#  'orange liqueur',
#  'chile',
#  'xanthan gum',
#  'icing',
#  'triple sec',
#  'lemon flavoring',
#  'light rum',
#  'green chili',
#  'angel',
#  'jicama',
#  'green grapes',
#  'red grapes',
#  'paraffin',
#  'almond flavoring',
#  'veg',
#  'katakuriko',
#  'turbinado sugar',
#  'gouda cheese',
#  'red chili',
#  'chops',
#  'spice powder',
#  'jasmine rice',
#  'fat buttermilk',
#  'almond flour',
#  'orzo pasta',
#  'trout',
#  'pie shells',
#  'blueberry pie filling',
#  'marsala wine',
#  'cream chicken',
#  'italian bread crumbs',
#  'parsley sprigs',
#  'white fish',
#  'sweet corn',
#  'coriander powder',
#  'fat sour cream',
#  'corn starch',
#  'candied pineapple',
#  'great northern beans',
#  'seasoning salt',
#  'mushroom stems',
#  'coconut cream',
#  'head cauliflower',
#  'pork loin chops',
#  'pancake mix',
#  'cream coconut',
#  'maraschino cherry',
#  'grits',
#  'tomato ketchup',
#  'caramel sauce',
#  'grenadine',
#  'sausages',
#  'peanut',
#  'nutritional yeast',
#  'turmeric powder',
#  'hamburg',
#  'dill pickle',
#  'strawberry gelatin',
#  'red chile',
#  'celery stalk',
#  'porcini mushrooms',
#  'champagne',
#  'salt pork',
#  'espresso',
#  'ground',
#  'pomegranate juice',
#  'guacamole',
#  'light cream cheese',
#  'sweet red peppers',
#  'dark sesame oil',
#  'caramel ice cream topping',
#  'mashed sweet potatoes',
#  'coarse ground black pepper',
#  'saffron threads',
#  'jello',
#  'crab',
#  'instant rice',
#  'chorizo',
#  'lima beans',
#  'nutella',
#  'alfredo sauce',
#  'sweet butter',
#  'choy',
#  'chervil',
#  'celery seeds',
#  'grated nutmeg',
#  'butternut',
#  'gelatine',
#  'pomegranate seeds',
#  'phyllo',
#  'white potatoes',
#  'lemonade concentrate',
#  'philadelphia',
#  'white balsamic vinegar',
#  'cream mushroom',
#  'grated monterey',
#  'containers',
#  'white syrup',
#  'yams',
#  'light coconut milk',
#  'rotini pasta',
#  'sugar snap peas',
#  'sriracha',
#  'chicken bouillon granules',
#  'baking mix',
#  'mashed bananas',
#  'vanilla essence',
#  'paper',
#  'dark chocolate',
#  'mint sprigs',
#  'chestnuts',
#  'tamari',
#  'grape jelly',
#  'sweet red bell peppers',
#  'summer',
#  'vermicelli',
#  'angel food cake',
#  'ground sirloin',
#  'watercress',
#  'italian seasoned breadcrumbs',
#  'apricot nectar',
#  'cardamom pods',
#  'broccoli flowerets',
#  'ground sage',
#  'vegetable soup',
#  'colby cheese',
#  'dark molasses',
#  'liquid',
#  'tarragon vinegar',
#  'cane sugar',
#  'hominy',
#  'radish',
#  'sriracha sauce',
#  'mixed greens',
#  'kosher',
#  'jumbo shrimp',
#  'breadcrumb',
#  'golden syrup',
#  'bbq sauce',
#  'acorn',
#  'bamboo shoots',
#  'bisquick baking mix',
#  'cherry jello',
#  'red lentils',
#  'sweet pickles',
#  'wheat',
#  'miracle whip',
#  'navy beans',
#  'brussels sprouts',
#  'endive',
#  'evoo',
#  'cornbread mix',
#  'golden brown sugar',
#  'beef roast',
#  'italian tomatoes',
#  'gruyere',
#  'mascarpone',
#  'sprouts',
#  ...]

# %%
ingredient_list = [x.replace(' ', '_') for x in ingredient_list]

# %%
ingredient_list
# Out:
# ['salt',
#  'sugar',
#  'butter',
#  'flour',
#  'eggs',
#  'onion',
#  'garlic',
#  'water',
#  'milk',
#  'vanilla',
#  'olive_oil',
#  'pepper',
#  'brown_sugar',
#  'egg',
#  'tomatoes',
#  'baking_powder',
#  'lemon_juice',
#  'cinnamon',
#  'parsley',
#  'cream_cheese',
#  'sour_cream',
#  'baking_soda',
#  'celery',
#  'chicken',
#  'margarine',
#  'cheddar_cheese',
#  'oil',
#  'vegetable_oil',
#  'onions',
#  'mayonnaise',
#  'parmesan_cheese',
#  'pecans',
#  'potatoes',
#  'kosher_salt',
#  'ground_black_pepper',
#  'basil',
#  'carrots',
#  'nuts',
#  'soy_sauce',
#  'black_pepper',
#  'pineapple',
#  'thyme',
#  'oregano',
#  'honey',
#  'bacon',
#  'mushrooms',
#  'unsalted_butter',
#  'chicken_broth',
#  'extra_virgin_olive_oil',
#  'mustard',
#  'ground_beef',
#  'cilantro',
#  'worcestershire_sauce',
#  'cornstarch',
#  'paprika',
#  'red_pepper',
#  'ginger',
#  'powdered_sugar',
#  'green_pepper',
#  'vinegar',
#  'lemon',
#  'green_onions',
#  'nutmeg',
#  'ground_cinnamon',
#  'rice',
#  'shortening',
#  'walnuts',
#  'chicken_breasts',
#  'heavy_cream',
#  'buttermilk',
#  'chili_powder',
#  'cheese',
#  'raisins',
#  'clove_garlic',
#  'bay',
#  'cocoa',
#  'red_onion',
#  'bread',
#  'orange_juice',
#  'purpose',
#  'white_sugar',
#  'soda',
#  'tomato_sauce',
#  'white_wine',
#  'mozzarella_cheese',
#  'coconut',
#  'chocolate_chips',
#  'zucchini',
#  'lime_juice',
#  'peanut_butter',
#  'shrimp',
#  'cayenne_pepper',
#  'carrot',
#  'bread_crumbs',
#  'ground_cumin',
#  'cream_mushroom_soup',
#  'boiling_water',
#  'strawberries',
#  'cream',
#  'apples',
#  'tomato',
#  'egg_yolks',
#  'bananas',
#  'egg_whites',
#  'almonds',
#  'broccoli',
#  'corn',
#  'cream_chicken_soup',
#  'canola_oil',
#  'rosemary',
#  'chocolate',
#  'tomato_paste',
#  'spinach',
#  'ketchup',
#  'mint',
#  'ground_pepper',
#  'oleo',
#  'chives',
#  'yeast',
#  'green_onion',
#  'red_bell_pepper',
#  'cumin',
#  'marshmallows',
#  'scallions',
#  'cloves',
#  'peas',
#  'sauce',
#  'whipping_cream',
#  'sausage',
#  'red_wine_vinegar',
#  'ham',
#  'sesame_oil',
#  'ground_ginger',
#  'green_beans',
#  'cabbage',
#  'beans',
#  'garlic_powder',
#  'ground_nutmeg',
#  'shallots',
#  'cucumber',
#  'lime',
#  'balsamic_vinegar',
#  'dill',
#  'oats',
#  'condensed_milk',
#  'cranberries',
#  'garlic_salt',
#  'breadcrumbs',
#  'maple_syrup',
#  'bell_pepper',
#  'blueberries',
#  'orange',
#  'hamburger',
#  'peanuts',
#  'lemon_zest',
#  'sage',
#  'chicken_stock',
#  'white_vinegar',
#  'beef',
#  'green_bell_pepper',
#  'curry_powder',
#  'stalks_celery',
#  'crackers',
#  'wheat_flour',
#  'light_brown_sugar',
#  'olives',
#  'onion_powder',
#  'pasta',
#  'ground_cloves',
#  'black_beans',
#  'swiss_cheese',
#  'cider_vinegar',
#  'black_olives',
#  'molasses',
#  'salsa',
#  'red_wine',
#  'avocado',
#  'pineapple_juice',
#  'cottage_cheese',
#  'apple',
#  'peaches',
#  'pumpkin',
#  'noodles',
#  'green_chilies',
#  'dry_mustard',
#  'yogurt',
#  'shallot',
#  'grated_cheese',
#  'yellow_onion',
#  'confectioners_sugar',
#  'allspice',
#  'dates',
#  'sesame_seeds',
#  'cream_tartar',
#  'lemons',
#  'peppers',
#  'white_pepper',
#  'banana',
#  'salmon',
#  'pork',
#  'catsup',
#  'flour_tortillas',
#  'feta_cheese',
#  'beef_broth',
#  'green_peppers',
#  'kidney_beans',
#  'salad_oil',
#  'tomato_soup',
#  'italian_seasoning',
#  'vanilla_extract',
#  'cornmeal',
#  'semi_sweet_chocolate_chips',
#  'velveeta_cheese',
#  'sherry',
#  'graham_cracker_crumbs',
#  'ricotta_cheese',
#  'oranges',
#  'sweet_potatoes',
#  'egg_yolk',
#  'capers',
#  'cauliflower',
#  'onion_soup',
#  'granulated_sugar',
#  'cucumbers',
#  'turmeric',
#  'raspberries',
#  'tarragon',
#  'light_corn_syrup',
#  'horseradish',
#  'white_wine_vinegar',
#  'tabasco_sauce',
#  'water_chestnuts',
#  'lean_ground_beef',
#  'topping',
#  'apple_cider_vinegar',
#  'kernel_corn',
#  'orange_zest',
#  'vanilla_ice_cream',
#  'coconut_milk',
#  'filling',
#  'rice_vinegar',
#  'coriander',
#  'barbecue_sauce',
#  'active_dry_yeast',
#  'crust',
#  'dressing',
#  'cake',
#  'tuna',
#  'pastry',
#  'macaroni',
#  'coffee',
#  'heavy_whipping_cream',
#  'chicken_breast',
#  'parsley_flakes',
#  'rolled_oats',
#  'ground_coriander',
#  'turkey',
#  'oatmeal',
#  'cayenne',
#  'cake_flour',
#  'almond',
#  'pork_chops',
#  'white_onion',
#  'crisco',
#  'cream_celery_soup',
#  'fish_sauce',
#  'parmesan',
#  'mushroom_soup',
#  'peanut_oil',
#  'cherry_pie_filling',
#  'mango',
#  'red',
#  'whipped_cream',
#  'red_potatoes',
#  'mandarin_oranges',
#  'syrup',
#  'pecan',
#  'corn_tortillas',
#  'corn_syrup',
#  'egg_noodles',
#  'american_cheese',
#  'chili_sauce',
#  'italian_dressing',
#  'white_bread',
#  'brandy',
#  'maraschino_cherries',
#  'tomato_juice',
#  'dill_weed',
#  'avocados',
#  'condensed_cream',
#  'red_peppers',
#  'ground_allspice',
#  'cherries',
#  'applesauce',
#  'shell',
#  'sweet_onion',
#  'bisquick',
#  'potato',
#  'apple_juice',
#  'shredded_cheese',
#  'taco',
#  'vegetable_broth',
#  'goat_cheese',
#  'chickpeas',
#  'eggplant',
#  'baby_spinach',
#  'rum',
#  'almond_extract',
#  'leeks',
#  'flat_parsley',
#  'vodka',
#  'flaked_coconut',
#  'lemon_rind',
#  'tortilla_chips',
#  'pimento',
#  'marjoram',
#  'pinto_beans',
#  'salad_dressing',
#  'vegetable_stock',
#  'cherry_tomatoes',
#  'cocoa_powder',
#  'vanilla_pudding',
#  'ground_pork',
#  'spaghetti_sauce',
#  'ground_turkey',
#  'mushroom',
#  'celery_salt',
#  'bread_flour',
#  'yellow_cake',
#  'vegetables',
#  'arugula',
#  'white_rice',
#  'buns',
#  'red_onions',
#  'brown_rice',
#  'pepperoni',
#  'yellow_cake_mix',
#  'red_bell_peppers',
#  'curry',
#  'crescent_rolls',
#  'vanilla_wafers',
#  'coconut_oil',
#  'scallion',
#  'ground_red_pepper',
#  'plain_yogurt',
#  'ginger_ale',
#  'mozzarella',
#  'vegetable',
#  'hearts',
#  'elbow_macaroni',
#  'italian_parsley',
#  'gingerroot',
#  'blue_cheese',
#  'green_olives',
#  'italian_sausage',
#  'long_grain_rice',
#  'skinless',
#  'broccoli_florets',
#  'cashews',
#  'ground_chuck',
#  'bell_peppers',
#  'crabmeat',
#  'mixed_vegetables',
#  'rhubarb',
#  'miracle',
#  'salad',
#  'unflavored_gelatin',
#  'light_cream',
#  'apple_cider',
#  'black_peppercorns',
#  'philadelphia_cream_cheese',
#  'vegetable_shortening',
#  'graham_crackers',
#  'cake_mix',
#  'icing_sugar',
#  'strawberry',
#  'lasagna_noodles',
#  'vanilla_bean',
#  'caster_sugar',
#  'pepper_sauce',
#  'cheddar',
#  'pumpkin_pie_spice',
#  'corn_flakes',
#  'rice_krispies',
#  'white_chocolate',
#  'cranberry_sauce',
#  'poultry_seasoning',
#  'head_lettuce',
#  'orange_rind',
#  'bittersweet_chocolate',
#  'pimentos',
#  'beer',
#  'cumin_seeds',
#  'pine_nuts',
#  'spaghetti',
#  'graham_cracker_crust',
#  'sauerkraut',
#  'butternut_squash',
#  'bourbon',
#  'cracker_crumbs',
#  'pork_sausage',
#  'confectioners',
#  'sake',
#  'beef_stock',
#  'baking_potatoes',
#  'pie_shell',
#  'bean_sprouts',
#  'gelatin',
#  'yellow_cornmeal',
#  'pork_tenderloin',
#  'beets',
#  'golden_raisins',
#  'liquid_smoke',
#  'mirin',
#  'garam_masala',
#  'romano_cheese',
#  'sweet_red_pepper',
#  'sunflower_seeds',
#  'tomato_puree',
#  'green_peas',
#  'corn_kernels',
#  'green_bell_peppers',
#  'romaine_lettuce',
#  'quinoa',
#  'lemon_pepper',
#  'hazelnuts',
#  'baking',
#  'strawberry_jello',
#  'mayo',
#  'yellow_squash',
#  'ingredients',
#  'ground_turmeric',
#  'cereal',
#  'onion_salt',
#  'herbs',
#  'chocolate_cake',
#  'squeezed_lemon_juice',
#  'asparagus',
#  'pizza_sauce',
#  'pumpkin_puree',
#  'dijon_mustard',
#  'ground_cardamom',
#  'rice_wine_vinegar',
#  'crab_meat',
#  'yellow_onions',
#  'fruit',
#  'couscous',
#  'hoisin_sauce',
#  'chocolate_syrup',
#  'blackberries',
#  'mix',
#  'vanilla_instant_pudding',
#  'green_chiles',
#  'wesson_oil',
#  'rolls',
#  'jalapenos',
#  'coloring',
#  'pistachios',
#  'provolone_cheese',
#  'cinnamon_sticks',
#  'lemonade',
#  'radishes',
#  'oyster_sauce',
#  'lime_zest',
#  'cracked_black_pepper',
#  'corn_oil',
#  'shredded_monterey_jack_cheese',
#  'shiitake_mushrooms',
#  'frosting',
#  'yellow_bell_pepper',
#  'greek_yogurt',
#  'linguine',
#  'lard',
#  'yellow_mustard',
#  'white_flour',
#  'butterscotch_chips',
#  'pretzels',
#  'whipped_topping',
#  'shredded_lettuce',
#  'fruit_cocktail',
#  'fennel',
#  'egg_white',
#  'lemon_peel',
#  'pie_crust',
#  'fat',
#  'garbanzo_beans',
#  'cream_corn',
#  'red_kidney_beans',
#  'unsweetened_applesauce',
#  'lemon_wedges',
#  'berries',
#  'italian_salad_dressing',
#  'cranberry_juice',
#  'cookies',
#  'grape_tomatoes',
#  'ground_white_pepper',
#  'poppy_seed',
#  'dark_rum',
#  'okra',
#  'bran',
#  'caramels',
#  'purpose_flour',
#  'lettuce',
#  'potato_chips',
#  'apricot',
#  'sweet_milk',
#  'chiles',
#  'jalapeno',
#  'celery_stalks',
#  'sweet_potato',
#  'apricots',
#  'tortillas',
#  'taco_seasoning',
#  'jalapeno_peppers',
#  'pimiento',
#  'coarse_salt',
#  'cubes',
#  'head_cabbage',
#  'croutons',
#  'milk_chocolate',
#  'spring_onions',
#  'currants',
#  'kale',
#  'orange_marmalade',
#  'vanilla_flavoring',
#  'corn_meal',
#  's',
#  'fennel_seeds',
#  'jalapeno_pepper',
#  'chili',
#  'snow_peas',
#  'tahini',
#  'sherry_vinegar',
#  'ginger_root',
#  'eggplants',
#  'peppercorns',
#  'picante_sauce',
#  'grapes',
#  'semi_sweet_chocolate',
#  'coriander_seeds',
#  'instant_vanilla_pudding',
#  'dough',
#  'apricot_preserves',
#  'sharp_cheese',
#  'ro_tel_tomatoes',
#  'onion_soup_mix',
#  'fish',
#  'bacon_bits',
#  'white',
#  'ground_meat',
#  'ground_mustard',
#  'cajun_seasoning',
#  'lamb',
#  'gruyere_cheese',
#  'enchilada_sauce',
#  'olive',
#  'meal',
#  'wine',
#  'baguette',
#  'pancetta',
#  'unsweetened_cocoa',
#  'green',
#  'hash_browns',
#  'sour_milk',
#  'anchovy',
#  'lemon_extract',
#  'clove',
#  'poppy_seeds',
#  'tapioca',
#  'chicken_thighs',
#  'green_cabbage',
#  'button_mushrooms',
#  'creme_fraiche',
#  'mustard_seeds',
#  'nonstick',
#  'worcestershire',
#  'sweet_paprika',
#  'chili_beans',
#  'red_food_coloring',
#  'penne_pasta',
#  'tequila',
#  'white_beans',
#  'baby_carrots',
#  'club_soda',
#  'taco_sauce',
#  'red_cabbage',
#  'oysters',
#  'onion_flakes',
#  'accent',
#  'pear',
#  'marshmallow_cream',
#  'unsweetened_chocolate',
#  'basmati_rice',
#  'wine_vinegar',
#  'milk_chocolate_chips',
#  'center',
#  'pasta_sauce',
#  'lemon_jello',
#  'walnut',
#  'cannellini_beans',
#  'marshmallow_creme',
#  'chocolate_pudding',
#  'anise',
#  'artichokes',
#  'mussels',
#  'white_chocolate_chips',
#  'italian_bread',
#  'clams',
#  'mascarpone_cheese',
#  'simple_syrup',
#  'teriyaki_sauce',
#  'meat',
#  'shredded_coconut',
#  'chilies',
#  'slivered_almonds',
#  'raspberry',
#  'germ',
#  'taco_seasoning_mix',
#  'marinade',
#  'saffron',
#  'russet_potatoes',
#  'pork_loin',
#  'ground_almonds',
#  'cheddar_cheese_soup',
#  'chicken_bouillon',
#  'baking_cocoa',
#  'stuffing_mix',
#  'marinara_sauce',
#  'dream_whip',
#  'black_eyed_peas',
#  'white_cake',
#  'arborio_rice',
#  'crunchy_peanut_butter',
#  'pork_shoulder',
#  'turkey_breast',
#  'prunes',
#  'caraway_seeds',
#  'pumpkin_seeds',
#  'oreo_cookies',
#  'sunflower_oil',
#  'white_onions',
#  'liqueur',
#  'grated_parmesan_cheese',
#  'sherry_wine',
#  'choice',
#  'muffins',
#  'peach',
#  'fat_milk',
#  'parsnips',
#  'tofu',
#  'pastry_shell',
#  'fennel_bulb',
#  'barley',
#  'ricotta',
#  'lentils',
#  'regular',
#  'corn_chips',
#  'orange_juice_concentrate',
#  'chili_pepper',
#  'vanilla_yogurt',
#  'mustard_powder',
#  'chicken_bouillon_cubes',
#  'wheat_bread',
#  'stock',
#  'flat',
#  'yellow_pepper',
#  'peppermint',
#  'orange_jello',
#  'wild_rice',
#  'gin',
#  'broth',
#  'caraway_seed',
#  'light_mayonnaise',
#  'roma_tomatoes',
#  'red_chili_pepper',
#  'long_grain_white_rice',
#  'cognac',
#  'orange_peel',
#  'green_tomatoes',
#  'nonfat_yogurt',
#  'pimientos',
#  'semisweet_chocolate',
#  'chuck_roast',
#  'cornflour',
#  'pet_milk',
#  'candied_cherries',
#  'mangoes',
#  'cantaloupe',
#  'gold_potatoes',
#  'nonfat_milk',
#  'biscuit_mix',
#  'brussels',
#  'maple',
#  'lobster',
#  'crisco_oil',
#  'squeezed_lime_juice',
#  'powdered_milk',
#  'grapeseed_oil',
#  'cornflakes',
#  'limes',
#  'flank_steak',
#  'splenda_sugar',
#  'bay_seasoning',
#  'scallops',
#  'white_corn_syrup',
#  'butter_beans',
#  'cherry',
#  'beef_bouillon',
#  'dried_basil',
#  'cardamom',
#  'salami',
#  'chile_powder',
#  'chickens',
#  'lump_crabmeat',
#  'black',
#  'brown_mustard',
#  'grand_marnier',
#  'lime_wedges',
#  'clam_juice',
#  'packet',
#  'kahlua',
#  'almond_milk',
#  'tart_apples',
#  'graham_cracker_pie_crust',
#  'salad_greens',
#  'crushed_ice',
#  'polenta',
#  'wheat_pastry_flour',
#  'sesame_seed',
#  'popcorn',
#  'splenda',
#  'grain_mustard',
#  'ghee',
#  'brownie_mix',
#  'steak_sauce',
#  'feta',
#  'vinaigrette',
#  'corn_muffin',
#  'salmon_fillet',
#  'rice_flour',
#  'red_chilies',
#  'sweet',
#  'sweet_onions',
#  'pineapple_tidbits',
#  'pears',
#  'light_sour_cream',
#  'bitters',
#  'hash_brown_potatoes',
#  'watermelon',
#  'lime_jello',
#  'espresso_powder',
#  'chunky_peanut_butter',
#  'sprinkles',
#  'stuffing',
#  'roll',
#  'green_chili_peppers',
#  'instant_coffee',
#  'white_mushrooms',
#  'steak',
#  'ground_lamb',
#  'nectar',
#  'biscuits',
#  'ready',
#  'food_coloring',
#  'dark_brown_sugar',
#  'purple_onion',
#  'ro_tel',
#  'figs',
#  'ground_cayenne_pepper',
#  'layer',
#  'anchovies',
#  'red_curry',
#  'ground_chicken',
#  'generous',
#  'rice_wine',
#  'kielbasa',
#  'tabasco',
#  'beef_brisket',
#  'beef_tenderloin',
#  'white_karo_syrup',
#  'pearl_barley',
#  'red_beans',
#  'cumin_powder',
#  'seasoning',
#  'italian',
#  'toppings',
#  'chocolate_cake_mix',
#  'sweet_basil',
#  'creole_seasoning',
#  'chunky_salsa',
#  'pesto_sauce',
#  'white_cake_mix',
#  'ramen_noodles',
#  'mace',
#  'pickles',
#  'sweet_chili_sauce',
#  'baby_arugula',
#  'pesto',
#  'chili_peppers',
#  'squash',
#  'smooth_peanut_butter',
#  'soymilk',
#  'cinnamon_sugar',
#  'penne',
#  'blanched_almonds',
#  'coffee_granules',
#  'squeezed_orange_juice',
#  'whiskey',
#  'swiss_chard',
#  'whip',
#  'vidalia_onion',
#  'deli',
#  'corned_beef',
#  'prawns',
#  'coconut_flakes',
#  'cremini_mushrooms',
#  'rice_noodles',
#  'red_chili_powder',
#  'wonton_wrappers',
#  'chili_flakes',
#  'doritos',
#  'dill_pickles',
#  'ranch_dressing',
#  'fettuccine',
#  'tater',
#  'apple_pie_filling',
#  'fennel_seed',
#  'ground_round',
#  'cracked_pepper',
#  'corn_bread',
#  'stew_meat',
#  'extra_lean_ground_beef',
#  'dutch',
#  'beef_stew_meat',
#  'sweet_pickle',
#  'velveeta',
#  'pasta_shells',
#  'meatballs',
#  'preserves',
#  'veal',
#  'chia_seeds',
#  'golden_raisin',
#  'orange_liqueur',
#  'chile',
#  'xanthan_gum',
#  'icing',
#  'triple_sec',
#  'lemon_flavoring',
#  'light_rum',
#  'green_chili',
#  'angel',
#  'jicama',
#  'green_grapes',
#  'red_grapes',
#  'paraffin',
#  'almond_flavoring',
#  'veg',
#  'katakuriko',
#  'turbinado_sugar',
#  'gouda_cheese',
#  'red_chili',
#  'chops',
#  'spice_powder',
#  'jasmine_rice',
#  'fat_buttermilk',
#  'almond_flour',
#  'orzo_pasta',
#  'trout',
#  'pie_shells',
#  'blueberry_pie_filling',
#  'marsala_wine',
#  'cream_chicken',
#  'italian_bread_crumbs',
#  'parsley_sprigs',
#  'white_fish',
#  'sweet_corn',
#  'coriander_powder',
#  'fat_sour_cream',
#  'corn_starch',
#  'candied_pineapple',
#  'great_northern_beans',
#  'seasoning_salt',
#  'mushroom_stems',
#  'coconut_cream',
#  'head_cauliflower',
#  'pork_loin_chops',
#  'pancake_mix',
#  'cream_coconut',
#  'maraschino_cherry',
#  'grits',
#  'tomato_ketchup',
#  'caramel_sauce',
#  'grenadine',
#  'sausages',
#  'peanut',
#  'nutritional_yeast',
#  'turmeric_powder',
#  'hamburg',
#  'dill_pickle',
#  'strawberry_gelatin',
#  'red_chile',
#  'celery_stalk',
#  'porcini_mushrooms',
#  'champagne',
#  'salt_pork',
#  'espresso',
#  'ground',
#  'pomegranate_juice',
#  'guacamole',
#  'light_cream_cheese',
#  'sweet_red_peppers',
#  'dark_sesame_oil',
#  'caramel_ice_cream_topping',
#  'mashed_sweet_potatoes',
#  'coarse_ground_black_pepper',
#  'saffron_threads',
#  'jello',
#  'crab',
#  'instant_rice',
#  'chorizo',
#  'lima_beans',
#  'nutella',
#  'alfredo_sauce',
#  'sweet_butter',
#  'choy',
#  'chervil',
#  'celery_seeds',
#  'grated_nutmeg',
#  'butternut',
#  'gelatine',
#  'pomegranate_seeds',
#  'phyllo',
#  'white_potatoes',
#  'lemonade_concentrate',
#  'philadelphia',
#  'white_balsamic_vinegar',
#  'cream_mushroom',
#  'grated_monterey',
#  'containers',
#  'white_syrup',
#  'yams',
#  'light_coconut_milk',
#  'rotini_pasta',
#  'sugar_snap_peas',
#  'sriracha',
#  'chicken_bouillon_granules',
#  'baking_mix',
#  'mashed_bananas',
#  'vanilla_essence',
#  'paper',
#  'dark_chocolate',
#  'mint_sprigs',
#  'chestnuts',
#  'tamari',
#  'grape_jelly',
#  'sweet_red_bell_peppers',
#  'summer',
#  'vermicelli',
#  'angel_food_cake',
#  'ground_sirloin',
#  'watercress',
#  'italian_seasoned_breadcrumbs',
#  'apricot_nectar',
#  'cardamom_pods',
#  'broccoli_flowerets',
#  'ground_sage',
#  'vegetable_soup',
#  'colby_cheese',
#  'dark_molasses',
#  'liquid',
#  'tarragon_vinegar',
#  'cane_sugar',
#  'hominy',
#  'radish',
#  'sriracha_sauce',
#  'mixed_greens',
#  'kosher',
#  'jumbo_shrimp',
#  'breadcrumb',
#  'golden_syrup',
#  'bbq_sauce',
#  'acorn',
#  'bamboo_shoots',
#  'bisquick_baking_mix',
#  'cherry_jello',
#  'red_lentils',
#  'sweet_pickles',
#  'wheat',
#  'miracle_whip',
#  'navy_beans',
#  'brussels_sprouts',
#  'endive',
#  'evoo',
#  'cornbread_mix',
#  'golden_brown_sugar',
#  'beef_roast',
#  'italian_tomatoes',
#  'gruyere',
#  'mascarpone',
#  'sprouts',
#  ...]

# %% [markdown]
# - identify presence of ingredients in n-gram modified instruction text (training data)

# %%
ingredient_count_ngrams = {}

def count_ingredients_ngrams(text):
    word_list = text.split(" ")

    for word in word_list:
        if word in ingredient_list:
            if word in ingredient_count_ngrams:
                ingredient_count_ngrams[word] = ingredient_count_ngrams[word] + 1
            else:
                ingredient_count_ngrams[word] = 1
                
                
    return ingredient_count_ngrams

# %%
# %%time
training_data['instructions_pp_ngrams'].apply(count_ingredients_ngrams)
# Out:
# CPU times: user 4h 36min 18s, sys: 20.7 s, total: 4h 36min 39s
# Wall time: 4h 37min 1s
# 0         {'heavy': 48867, 'mix': 1310617, 'brown': 381996, 'sugar': 862752, 'nuts': 112238, 'evaporated_m...
# 1         {'heavy': 48867, 'mix': 1310617, 'brown': 381996, 'sugar': 862752, 'nuts': 112238, 'evaporated_m...
# 2         {'heavy': 48867, 'mix': 1310617, 'brown': 381996, 'sugar': 862752, 'nuts': 112238, 'evaporated_m...
# 3         {'heavy': 48867, 'mix': 1310617, 'brown': 381996, 'sugar': 862752, 'nuts': 112238, 'evaporated_m...
# 4         {'heavy': 48867, 'mix': 1310617, 'brown': 381996, 'sugar': 862752, 'nuts': 112238, 'evaporated_m...
#                                                          ...
# 522511    {'heavy': 48867, 'mix': 1310617, 'brown': 381996, 'sugar': 862752, 'nuts': 112238, 'evaporated_m...
# 522512    {'heavy': 48867, 'mix': 1310617, 'brown': 381996, 'sugar': 862752, 'nuts': 112238, 'evaporated_m...
# 522513    {'heavy': 48867, 'mix': 1310617, 'brown': 381996, 'sugar': 862752, 'nuts': 112238, 'evaporated_m...
# 522514    {'heavy': 48867, 'mix': 1310617, 'brown': 381996, 'sugar': 862752, 'nuts': 112238, 'evaporated_m...
# 522516    {'heavy': 48867, 'mix': 1310617, 'brown': 381996, 'sugar': 862752, 'nuts': 112238, 'evaporated_m...
# Name: instructions_pp_ngrams, Length: 2353441, dtype: object

# %%
ingredient_count_ngrams
# Out:
# {'heavy': 48867,
#  'mix': 1310617,
#  'brown': 381996,
#  'sugar': 862752,
#  'nuts': 112238,
#  'evaporated_milk': 11251,
#  'butter': 680399,
#  'margarine': 81923,
#  'medium': 620670,
#  'heat': 1503923,
#  'mixture': 1181963,
#  'boil': 282856,
#  'minutes': 2723346,
#  'vanilla': 240369,
#  'cereal': 16746,
#  'drop': 57024,
#  'clusters': 894,
#  'place': 1038182,
#  'chipped_beef': 543,
#  'chicken': 523162,
#  'beef': 115613,
#  'soup': 177889,
#  'cream': 268812,
#  'pour': 763702,
#  'hours': 248578,
#  'slow_cooker': 20815,
#  'combine': 787439,
#  'ingredients': 636308,
#  'cover': 643493,
#  'cook': 1172832,
#  'cheese': 438173,
#  'serving': 219907,
#  'square': 30872,
#  'gravy': 28893,
#  'mushroom_soup': 11500,
#  'level': 10034,
#  'stuffing': 33760,
#  'shredded_cheese': 13914,
#  'bake': 974039,
#  'approximately': 54982,
#  'golden': 100026,
#  'spread': 349233,
#  'refrigerate': 128313,
#  'chocolate': 147135,
#  'refrigerator': 69190,
#  'wash': 45450,
#  'potatoes': 245180,
#  'fork': 93289,
#  'microwave': 68631,
#  'wet': 20521,
#  'ready_eat': 3650,
#  'handle': 8060,
#  'reserve': 58160,
#  'shells': 23116,
#  'ground_beef': 43037,
#  'grease': 80841,
#  'meat': 278467,
#  'flour': 652959,
#  'smooth': 277395,
#  'milk': 389319,
#  'potato': 52180,
#  'salt_pepper': 340011,
#  'green': 76320,
#  'onion': 456885,
#  'bacon': 125237,
#  'remaining': 576469,
#  'green_onions': 36816,
#  'egg': 239101,
#  'salt': 618928,
#  'soda': 39721,
#  'rhubarb': 11583,
#  'topping': 57298,
#  'cans': 10419,
#  'corn': 70381,
#  'crackers': 36801,
#  'pepper': 295734,
#  'buttered': 37084,
#  'dot': 6597,
#  'hour': 289499,
#  'roll': 218811,
#  'steak_strips': 1219,
#  'skillet': 367555,
#  'tomato': 74218,
#  'liquid': 112453,
#  'water': 819821,
#  'onions': 237824,
#  'steak': 45934,
#  'simmer': 369852,
#  'quarter': 16220,
#  'worcestershire_sauce': 16896,
#  'tomatoes': 185313,
#  'green_peppers': 7606,
#  'serve': 607308,
#  'rice': 232245,
#  'juice': 82783,
#  'pineapple': 54638,
#  'condensed_milk': 6591,
#  'seeds': 35085,
#  'chop': 77029,
#  'crust': 134692,
#  'use': 251688,
#  'pie': 69491,
#  'cherries': 22772,
#  'syrup': 78087,
#  'almond_extract': 8084,
#  'chill': 135119,
#  'marshmallows': 26190,
#  'spoon': 247775,
#  'makes': 48372,
#  'peanut_butter': 40642,
#  'cookie_sheet': 45105,
#  'way': 30913,
#  'chocolate_chip': 1360,
#  'paraffin': 586,
#  'clean': 54346,
#  'wings': 13710,
#  'barbecue_sauce': 10960,
#  'taco_sauce': 2748,
#  'pizza': 32392,
#  'taco_seasoning': 8408,
#  'layer': 189767,
#  'chips': 38181,
#  'cornstarch': 62400,
#  'saucepan': 255327,
#  'clear': 14078,
#  'jello': 15016,
#  'strawberries': 34379,
#  'cooled': 56390,
#  'glaze': 51826,
#  'berries': 28623,
#  'whipped_cream': 23574,
#  'oil': 589355,
#  'trim': 13846,
#  'broccoli': 54590,
#  'lower': 30498,
#  'stalks': 4044,
#  'thoroughly': 98061,
#  'raisins': 38267,
#  'dressing': 95841,
#  'gently': 162226,
#  'crushed': 13923,
#  'bananas': 26872,
#  'gel': 1110,
#  'sour_cream': 59889,
#  'crisco': 9460,
#  'applesauce': 12950,
#  'shortening': 50918,
#  'eggs': 292941,
#  'mints': 672,
#  'cake': 268900,
#  'directions': 21359,
#  'buy': 2955,
#  'turkey_breast': 2865,
#  'marinade': 63149,
#  'turkey': 53449,
#  'ground': 24598,
#  'peppers': 74302,
#  'garlic': 397643,
#  'moderate': 9383,
#  'oven': 519734,
#  'cajun': 543,
#  'game': 455,
#  'beans': 117915,
#  's': 84839,
#  'world': 448,
#  'braising': 966,
#  'briefly': 13823,
#  'long': 38450,
#  'time': 177875,
#  'strips': 51538,
#  'drippings': 19203,
#  'tomato_sauce': 41315,
#  'sauce': 476514,
#  'slowly': 90160,
#  'tender': 278894,
#  'noodles': 93626,
#  'chocolate_chips': 42174,
#  'unsweetened_chocolate': 1210,
#  'taco': 3842,
#  'boiling_water': 79406,
#  'filling': 153840,
#  'boiling': 50685,
#  'yeast': 40295,
#  'batter': 182002,
#  'sticky': 11586,
#  'rolls': 46833,
#  'quart': 42376,
#  'fruit': 72893,
#  'apples': 78163,
#  'leave': 59113,
#  'peeling': 1627,
#  'dice': 23444,
#  'grapes': 7895,
#  'added': 23403,
#  'cherry_pie': 3845,
#  'dry': 136969,
#  'rack': 78438,
#  'macaroni': 24788,
#  'pimento': 4060,
#  'artichokes': 12658,
#  'mayonnaise': 60942,
#  'parmesan_cheese': 44385,
#  'mixed': 56796,
#  'vegetable': 28787,
#  'spaghetti': 21841,
#  'melt': 65976,
#  'salad_supreme': 179,
#  'zesty_italian_dressing': 116,
#  'cucumbers': 14625,
#  'mushrooms': 131384,
#  'olives': 29460,
#  'want': 51206,
#  'pears': 18333,
#  'reserving_juice': 1130,
#  'gelatin': 29129,
#  'slightly': 107584,
#  'cream_cheese': 136854,
#  'yogurt': 47628,
#  'pink': 7345,
#  'parts': 8459,
#  'watermelon_rind': 194,
#  'cubes': 39191,
#  'vinegar': 129508,
#  'cloves': 19231,
#  'cinnamon': 107587,
#  'rind': 6106,
#  'clove': 2095,
#  'bone': 10090,
#  'broth': 116856,
#  'vegetables': 154217,
#  'black_pepper': 40894,
#  'fat': 56382,
#  'granulated_sugar': 10097,
#  'baking_powder': 115736,
#  'baking': 147527,
#  'buttermilk': 47067,
#  'candy': 11924,
#  'wrap': 49106,
#  'marshmallow': 6108,
#  'edges': 76752,
#  'dough': 390320,
#  'pans': 63453,
#  'mint': 22562,
#  'drizzle': 112054,
#  'saute': 236012,
#  'curry_powder': 12653,
#  'cubed': 6248,
#  'grated_cheese': 21047,
#  'egg_yolks': 32133,
#  'center': 122570,
#  'rings': 8103,
#  'cookie': 31909,
#  'candies': 3636,
#  'baking_sheets': 28048,
#  'golden_brown': 155122,
#  'racks': 6157,
#  'pot': 250950,
#  'overnight': 49222,
#  'slaw': 4955,
#  'fillets': 15859,
#  'platter': 46155,
#  'garnish': 95306,
#  'salad': 83241,
#  'corns': 206,
#  'bread': 165643,
#  'seasonings': 38386,
#  'cabbage': 45266,
#  'carefully': 68837,
#  'lump_crab': 126,
#  'ahead_time': 3869,
#  'hold': 21223,
#  'better': 12241,
#  'freeze': 54141,
#  'tortilla_chips': 12124,
#  'hands': 40925,
#  'day': 29054,
#  'box': 6979,
#  'powdered_sugar': 29896,
#  'lemon_juice': 133349,
#  'rich': 4825,
#  'puree': 47452,
#  'peaches': 25128,
#  'blender': 69237,
#  'blend': 203017,
#  'blueberries': 17082,
#  'diameter': 9820,
#  'cocoa': 40730,
#  'addition': 22895,
#  'cake_pans': 8070,
#  'apple': 42620,
#  'sour_cream_cheese': 2214,
#  'cornflakes': 2694,
#  'vanilla_wafer': 1283,
#  'crumbs': 51435,
#  'cornflake_crumbs': 669,
#  'oleo': 14164,
#  'sausage': 76777,
#  'bisquick': 4577,
#  'consomme': 1813,
#  'season_salt': 131157,
#  'celery': 58541,
#  'mustard': 62989,
#  'catsup': 4866,
#  'chicken_broth': 40398,
#  'beaten_egg': 14247,
#  'times': 31577,
#  'rolling_pin': 4973,
#  'coat': 152604,
#  'grill': 141547,
#  'coals': 5797,
#  'soy_sauce': 34685,
#  'desired': 143951,
#  'separate': 77957,
#  'cheddar_cheese': 17187,
#  'orange': 21005,
#  'cranberry': 4802,
#  'mold': 19832,
#  'walnuts': 35607,
#  'whip': 31115,
#  'round': 44237,
#  'corn_chips': 3945,
#  'finger': 5081,
#  'velveeta': 4139,
#  'squash': 48828,
#  'carrots': 80343,
#  'mash': 35357,
#  'cheddar_cheeses': 119,
#  'items': 2847,
#  'liquids': 5128,
#  'food': 8070,
#  'molds': 6012,
#  'mixer': 55059,
#  'flavoring': 6873,
#  'pudding': 61157,
#  'break': 38392,
#  'loaf': 33744,
#  'second': 32033,
#  'rise': 10299,
#  'sides': 200028,
#  'diced': 23720,
#  'bouillon_cubes': 3561,
#  'angel_hair': 244,
#  'good': 41419,
#  'pecans': 61885,
#  'griddle': 13545,
#  'zucchini': 52836,
#  'ham': 50994,
#  'minute': 193237,
#  'red': 33865,
#  'peel': 82651,
#  'bacon_crisp': 8051,
#  'bacon_drippings': 5378,
#  'paste': 41944,
#  'towel': 10019,
#  'lid': 50397,
#  'container': 38145,
#  'ready_serve': 26575,
#  'heaping': 5502,
#  'hamburg': 980,
#  'crumble': 24596,
#  'manwich': 156,
#  'lime': 12968,
#  'pitcher': 9743,
#  'wine': 73573,
#  'sangria': 440,
#  'sweeter': 924,
#  'cornbread': 8986,
#  'oats': 28464,
#  'baking_sheet': 153205,
#  'chinese_noodles': 640,
#  'tuna': 21896,
#  'cashews': 6854,
#  'peas': 41228,
#  'reserved': 62064,
#  'power': 4922,
#  'thawed': 5367,
#  'adding': 75334,
#  'dill': 17391,
#  'juices': 44525,
#  'parsley': 118669,
#  'cracker': 3926,
#  'kind': 4100,
#  'muffin': 34352,
#  'pat': 33215,
#  'wooden_spoon': 23266,
#  'following': 4921,
#  'vegetable_oil': 31134,
#  'chili_powder': 22652,
#  'nectar': 923,
#  'honey': 67477,
#  'almonds': 43111,
#  'paprika': 36201,
#  'chicken_stock': 23891,
#  'french_bread': 4047,
#  'broiler': 30138,
#  'unbaked_pie_shell': 1988,
#  'brush': 117219,
#  'hamburger': 12723,
#  'lemon': 42587,
#  'flavor': 21058,
#  'yellow_food_coloring': 378,
#  'depending': 12590,
#  'meringue': 18975,
#  'tater_tots': 758,
#  'heavy_saucepan': 17978,
#  'blackberries': 3469,
#  'pastry_shell': 4683,
#  'ice_cream': 55782,
#  'pie_crusts': 2598,
#  'coconut': 68753,
#  'almond': 12306,
#  'pies': 5474,
#  'caramel_topping': 1763,
#  'cherry_tomatoes': 5189,
#  'green_beans': 18993,
#  'tomato_juice': 6952,
#  'glass': 65630,
#  'sugars': 13751,
#  'vanilla_wafers': 1987,
#  'stove': 28242,
#  'gelatine': 2165,
#  'spices': 56188,
#  'pumpkin': 31661,
#  'italian_bread': 997,
#  'hominy': 1837,
#  'tamales': 1454,
#  'spanish_rice': 517,
#  'spatula': 32554,
#  'doritos': 1639,
#  'potato_flakes': 1156,
#  'stock': 79205,
#  'artichoke_hearts': 3680,
#  'instant_pudding': 1955,
#  'ginger_ale': 1698,
#  'pistachio': 1267,
#  'sherbert': 101,
#  'watch': 4251,
#  'seasoning': 35818,
#  'pie_shell': 22679,
#  'paper': 41911,
#  'breasts': 7699,
#  'mixtures': 4382,
#  'according': 3870,
#  'knife': 38873,
#  'corned_beef_hash': 123,
#  'lengthwise': 16700,
#  'corn_flakes': 4139,
#  'pie_crust': 23537,
#  'knead': 26256,
#  'biscuits': 30194,
#  'cookie_sheets': 15636,
#  'spaghetti_sauce': 9223,
#  'mozzarella': 16643,
#  'ricotta': 15175,
#  'tart': 20814,
#  'pie_plate': 29195,
#  'mashed_potatoes': 12691,
#  'egg_white': 22116,
#  'sheet': 70526,
#  'mozzarella_cheese': 14485,
#  'biscuit': 13330,
#  'chocolate_wafer': 378,
#  'brownies': 10009,
#  'light_brown': 16110,
#  'cracked': 1411,
#  'candy_bars': 1687,
#  'white': 60524,
#  'sections': 5912,
#  'v': 823,
#  'baking_soda': 79036,
#  'tins': 4734,
#  'croutons': 11097,
#  'powder': 39604,
#  'fluffy': 30215,
#  'cinnamon_nutmeg': 11875,
#  'lots': 4892,
#  'bags': 3592,
#  'possible': 20758,
#  'line': 73205,
#  'cheesecloth': 4284,
#  'mandarin_juice': 103,
#  'electric': 3619,
#  'mandarin': 222,
#  'whipping_cream': 11341,
#  'garlic_powder': 33590,
#  'herb': 7820,
#  'starch': 2534,
#  'horseradish_mustard': 472,
#  'roast': 97318,
#  'tapioca': 3994,
#  'orange_juice': 31854,
#  'oranges': 10074,
#  'lime_sherbet': 169,
#  'bacon_fat': 6614,
#  'bag': 32773,
#  'pork': 94567,
#  'minced_garlic': 9500,
#  'green_chilies': 4156,
#  'diced_tomatoes': 6972,
#  'wax_paper': 10514,
#  'finish': 19373,
#  'whipped_cream_topping': 400,
#  'blue_cheese': 5948,
#  'graham_cracker_crumbs': 5809,
#  'ice_cubes': 8841,
#  'cherry': 10867,
#  'crescent_rolls': 2903,
#  'frosting': 46638,
#  'pancakes': 12891,
#  'big': 17132,
#  'restaurant': 635,
#  'plate': 109777,
#  'savory': 1668,
#  'smoked_sausage': 808,
#  'sweet': 15379,
#  'plain': 10294,
#  'molasses': 16323,
#  'steam': 26381,
#  'instead': 15072,
#  'whipped_topping': 11070,
#  'sifter': 621,
#  'rounding': 119,
#  'ice': 53001,
#  'bean': 14705,
#  'crumbles': 2418,
#  'sour_milk': 1681,
#  'beer': 15836,
#  'oregano': 32740,
#  'quarters': 12497,
#  'dumplings': 10261,
#  'twinkies': 491,
#  'decorate': 12373,
#  'coffee': 21697,
#  'tomato_paste': 27570,
#  'shallow_baking': 16390,
#  'tortillas': 40736,
#  'dipping': 9393,
#  'bones': 10219,
#  'stew': 15270,
#  'onion_rings': 6377,
#  'caramel': 27479,
#  'chilled': 44237,
#  'pastry_blender': 7120,
#  'bread_crumbs': 50390,
#  'mushroom_stems': 1571,
#  'mushroom_caps': 3001,
#  'vegies': 700,
#  'veggies': 28078,
#  'crisp': 59720,
#  'cookie_dough': 7765,
#  'cutting_board': 14435,
#  'roasted': 16174,
#  'ovenproof': 5261,
#  'marshmallow_cream': 2157,
#  'sandwich': 20568,
#  'raisin': 2330,
#  'cheddar': 6612,
#  'iron_skillet': 3136,
#  'helper': 115,
#  'sesame_oil': 15730,
#  'juice_concentrate': 523,
#  'beaten_eggs': 13144,
#  'clams': 10570,
#  'cranberries': 19757,
#  'frankfurters': 640,
#  'graham_crackers': 6718,
#  'jell': 9141,
#  'milnot': 366,
#  'whites': 11044,
#  'foam': 4020,
#  'cream_tartar': 6999,
#  'pie_shells': 3644,
#  'crumb_mixture': 8628,
#  'confectioners_sugar': 4496,
#  'bacon_bits': 4349,
#  'corn_syrup': 18041,
#  'pulp': 9202,
#  'peanuts': 16651,
#  'tortilla': 32390,
#  'flat': 27365,
#  'fruits': 5889,
#  'beets': 17849,
#  'canned_beets': 69,
#  'necessary': 53556,
#  'food_processor': 25429,
#  'processor': 8555,
#  'cayenne_pepper': 11275,
#  'shallow': 34805,
#  'avocado': 24468,
#  'person': 3430,
#  'create': 13533,
#  'delicious': 12903,
#  'cones': 1250,
#  'glasses': 9708,
#  'jars': 15698,
#  'cone': 1935,
#  'juicy': 3110,
#  'egg_yolk': 15218,
#  'nonstick_skillet': 13467,
#  'cube': 8422,
#  'lard': 5474,
#  'bouillon': 9307,
#  'meatballs': 32546,
#  'preference': 2964,
#  'microwave_safe': 15163,
#  'maraschino_cherries': 1029,
#  'water_chestnuts': 6813,
#  'sweet_n': 526,
#  'sour': 2339,
#  'olive_oil': 69865,
#  'check': 18757,
#  'jelly': 10693,
#  'pepperoni': 5926,
#  'browns': 4398,
#  'tubular': 50,
#  'crock_pot': 14157,
#  'burgers': 11533,
#  'nutmeg': 33377,
#  'sweet_potatoes': 17891,
#  'poke': 2920,
#  'roux': 8539,
#  'easy': 8868,
#  'moisten': 9007,
#  'ready': 43570,
#  'foil': 117822,
#  'chocolate_melts': 2265,
#  'seconds': 91266,
#  'strawberry': 10647,
#  'tamari': 1782,
#  'chicken_breasts': 19266,
#  'tarragon': 8978,
#  'replace': 6598,
#  'box_jello': 145,
#  'shrimp': 98553,
#  'peanut_butter_chips': 1629,
#  'dates': 10345,
#  'yellow': 10720,
#  'great': 13428,
#  'stick': 32828,
#  'graham_cracker': 1632,
#  'shredded_cabbage': 1713,
#  'vitamin': 208,
#  'lay': 42965,
#  'sauerkraut': 6890,
#  'caraway_seed': 1171,
#  'rye_bread': 1514,
#  'red_pepper': 38773,
#  'looks': 3892,
#  'peeled': 6695,
#  'oysters': 6537,
#  'crusts': 6722,
#  'oatmeal': 12684,
#  'banana': 20983,
#  'bit': 48113,
#  'salmon': 38595,
#  'patties': 29393,
#  'fish': 99686,
#  'ladle': 16073,
#  'bath': 3380,
#  'rub': 47012,
#  'scoop': 32186,
#  'flakes': 25517,
#  'reduce': 46483,
#  'coconut_pecan': 348,
#  'icing': 32059,
#  'iron': 2839,
#  'omelet': 4039,
#  'rolled': 7800,
#  'circle': 23518,
#  'wedges': 23064,
#  'sprinkling': 7009,
#  'cooker': 5401,
#  'mushroom': 19130,
#  'broil': 39061,
#  'alum': 564,
#  'days': 21877,
#  'chilled_ginger_ale': 222,
#  'ham_bone': 1320,
#  'putting': 5739,
#  'toast': 39970,
#  'electric_blender': 1126,
#  'consistency': 24307,
#  'mazola_oil': 67,
#  'pineapple_juice': 14776,
#  'orange_jello': 390,
#  'measure': 24897,
#  'cookies': 83123,
#  'begin': 16761,
#  'salad_dressing': 11702,
#  'squeeze': 22384,
#  'cherry_juice': 1608,
#  'red_food_coloring': 1720,
#  'spinach': 69633,
#  'corn_tortillas': 2353,
#  'chili': 34688,
#  'fingers': 21886,
#  'celery_seed': 4336,
#  'omit': 5032,
#  'pastry': 56944,
#  'layers': 34142,
#  'liver': 4227,
#  'basil': 55913,
#  'range': 840,
#  'lemon_extract': 2359,
#  'shredded_cheddar': 3406,
#  'nacho_chips': 902,
#  'snacks': 565,
#  'stack': 8209,
#  'ring': 7353,
#  'powdered_sugar_icing': 411,
#  'note': 45710,
#  'realemon': 129,
#  'corn_meal': 4237,
#  'salsa': 35853,
#  'bouillon_cube': 2053,
#  'choco_bake': 46,
#  'dessert': 7959,
#  'breadcrumbs': 21932,
#  'liters': 149,
#  'boned': 360,
#  'plastic_wrap': 23017,
#  'cutlet': 1410,
#  'sage': 12671,
#  'parmesan': 31390,
#  'butterscotch_chips': 2024,
#  'custard': 29583,
#  'logs': 5093,
#  'ginger': 58587,
#  'mango': 10340,
#  'leek': 8636,
#  'safflower_oil': 262,
#  'dills': 70,
#  'brine': 7754,
#  'carrot': 25396,
#  'stewed_tomatoes': 1755,
#  'oyster': 2357,
#  'thickly': 1468,
#  'follow_directions': 1552,
#  'swirls': 763,
#  'cast_iron_skillet': 7494,
#  'nonstick': 11455,
#  'crabmeat': 6898,
#  'rounds': 18508,
#  'sandwiches': 15888,
#  'batches': 29373,
#  'pecan': 5021,
#  'wheat_flour': 4770,
#  'colander': 14755,
#  'skin': 64200,
#  'skin_bone': 638,
#  'thighs': 2923,
#  'sweet_relish': 182,
#  'n': 4203,
#  'purple_cabbage': 113,
#  'thyme': 41268,
#  'herbs': 25895,
#  'corn_cob': 771,
#  'greens': 19701,
#  'dirt': 1165,
#  'come': 12735,
#  'run': 11705,
#  'bourbon': 6816,
#  'halfway': 16179,
#  'color': 23446,
#  'bottoms': 9014,
#  'crumb': 4022,
#  'shake_n': 227,
#  'toothpicks': 4956,
#  'cracker_crumbs': 9746,
#  'night': 6778,
#  'envelope': 882,
#  'bread_cubes': 11702,
#  'hamburger_patty': 259,
#  'coating': 15927,
#  'muffins': 16881,
#  'achiote': 248,
#  'pimentos': 2147,
#  'chicken_breast': 18154,
#  'marinate': 25882,
#  'creamed_corn': 1237,
#  'drops_red': 693,
#  'coloring': 1596,
#  'pizza_crust': 3074,
#  'pizza_stone': 2869,
#  'cornmeal': 23136,
#  'rolling': 9124,
#  'fondant': 1460,
#  'olive_oil_garlic': 5613,
#  'rosemary': 22490,
#  'cooling_rack': 8329,
#  'bologna': 731,
#  'party': 1896,
#  'hotdogs': 341,
#  'crumbly': 17133,
#  'shell': 21146,
#  'drops': 6903,
#  'orange_rind': 3666,
#  'sherry': 13864,
#  'parkay': 123,
#  'basic': 2065,
#  'coal': 229,
#  'cheeses': 20060,
#  'red_peppers': 4824,
#  'wrapper': 3913,
#  'leeks': 17010,
#  'open': 25055,
#  'rouille': 319,
#  'work': 23152,
#  'crushed_ice': 3008,
#  'mashed_bananas': 2951,
#  'cupcakes': 12027,
#  'cakes': 23540,
#  'pancake': 10243,
#  'lingonberries': 96,
#  'grind': 13645,
#  'lettuce': 30931,
#  'radishes': 4964,
#  'wish': 9200,
#  'sesame_seeds': 16881,
#  'jam': 19706,
#  'outside': 14673,
#  'crockpot': 8939,
#  'cupcake_holders': 81,
#  'later': 13537,
#  'sprite': 782,
#  'grape_juice': 1143,
#  'moisture': 4640,
#  'easier': 7813,
#  'skins': 11150,
#  'save': 16743,
#  'chair': 91,
#  'special': 1389,
#  'family': 1999,
#  'apple_juice': 6581,
#  'bits': 12120,
#  'mayo': 12841,
#  'grate': 17474,
#  'swiss_cheese': 4124,
#  'save_juice': 1179,
#  'beaten': 4019,
#  'real': 3961,
#  'boned_chicken': 210,
#  'seven': 1693,
#  'pumpkin_spice': 594,
#  'dream_whip': 853,
#  'tear': 8059,
#  'ricotta_cheese': 6140,
#  'rum': 15128,
#  'dark_brown': 4029,
#  'spice': 23180,
#  'lighter': 1220,
#  'careful': 15917,
#  'peppercorns': 7135,
#  'chestnuts': 4117,
#  'persimmon_pulp': 299,
#  'baby_food': 614,
#  'breads': 2251,
#  'bell_pepper': 5980,
#  'mullet': 38,
#  'ribs': 31380,
#  'easily': 11101,
#  'pyrex': 2817,
#  'olive_oil_butter': 3925,
#  'sauteing': 1469,
#  'italian_seasoning': 8752,
#  'cranberry_sauce': 5753,
#  'egg_whites': 29926,
#  'season': 100625,
#  'stems': 13962,
#  'caps': 2485,
#  'rye_crackers': 87,
#  'grated_swiss': 240,
#  'monterey_jack_cheese': 1867,
#  'follow': 3308,
#  'wet_ingredients': 14624,
#  'optionals': 59,
#  'poppy_seeds': 2303,
#  'light': 30002,
#  'yolks': 17753,
#  'rectangular': 3328,
#  'chip': 1420,
#  'guacamole': 3755,
#  'raspberries': 11719,
#  'extra': 30831,
#  'orange_lemon': 1987,
#  'lemon_peel': 10349,
#  'apricot_nectar': 622,
#  'pork_chops': 19193,
#  'm': 1992,
#  'horizontally': 2577,
#  'capers': 8391,
#  'dried': 15683,
#  'decoration': 2040,
#  'cooks': 9937,
#  'ranch_dressing': 3748,
#  'nut_meats': 462,
#  'pasta': 145300,
#  'picante_sauce': 2418,
#  'st': 1425,
#  'including': 5047,
#  'shredded_carrot': 385,
#  'envelopes': 223,
#  'remember': 5651,
#  'fruit_choice': 376,
#  'dust': 18260,
#  'left': 17768,
#  'eggplant': 31495,
#  'cauliflower': 21450,
#  'poppy_seed': 1254,
#  'coarsely': 2835,
#  'pickles': 7926,
#  'relish': 6516,
#  'shallots': 34643,
#  'double': 10026,
#  'jalapeno_peppers': 2328,
#  'crawfish_tails': 557,
#  'tops': 31060,
#  'grated_cheddar': 2564,
#  'crumbled': 5340,
#  'soaked': 5364,
#  'persimmons': 552,
#  'persimmon': 485,
#  'loaves': 12939,
#  'portions': 11720,
#  'sharp': 2212,
#  'crepe_batter': 613,
#  'crepe': 6402,
#  'crepes': 5194,
#  'italian_dressing': 3531,
#  'scramblers': 16,
#  'feta': 8505,
#  'sheets': 17044,
#  'brushing': 4462,
#  'nice': 20468,
#  'luster': 23,
#  'cuts': 3688,
#  'type': 4778,
#  'heavy_cream': 21863,
#  'tortellini': 3460,
#  'extract': 9010,
#  'surface': 44116,
#  'regular': 7391,
#  'haddock': 494,
#  'scalded_milk': 1298,
#  'melts': 12242,
#  'pie_filling': 13107,
#  'mixes': 1237,
#  'popcorn': 8346,
#  'pretzels': 5921,
#  'shoyu': 443,
#  'lamb': 30434,
#  'tube': 3816,
#  'italian_bread_crumbs': 308,
#  'cinnamon_stick': 7056,
#  'cantaloupe': 1525,
#  'diet': 803,
#  'anchovies': 5199,
#  'cognac': 2558,
#  'larger': 14636,
#  'cereals': 475,
#  'pretzel_sticks': 319,
#  'fruit_cocktail': 2059,
#  'paper_liners': 2883,
#  'scallops': 15078,
#  'kielbasa': 2636,
#  'thaw': 9987,
#  'pizzas': 2654,
#  'english_walnuts': 75,
#  'walnut': 3891,
#  'ring_mold': 2047,
#  'crushed_cornflakes': 599,
#  'noodle': 5232,
#  'wooden_toothpicks': 201,
#  'oreo_cookies': 648,
#  'lasagna': 4965,
#  'crunchy': 5758,
#  'gin': 1463,
#  'fritos': 1545,
#  'julienne_strips': 593,
#  'crystal': 363,
#  'combination': 3386,
#  'lime_jell': 209,
#  'orange_jell': 161,
#  'mandarin_oranges': 1492,
#  'option': 2308,
#  'circles': 9123,
#  'triangles': 7873,
#  'flower_pot': 268,
#  'oreos': 1497,
#  'catalina_dressing': 280,
#  'breast': 13894,
#  'white_wine': 14088,
#  'toppings': 7151,
#  'shredded_coconut': 2092,
#  'ketchup': 17575,
#  'butterscotch': 1639,
#  'semi_sweet_chocolate_morsels': 113,
#  'ahead': 15843,
#  'alternate': 3992,
#  'kabob': 148,
#  ...}

# %%
ingredient_count = pd.DataFrame(ingredient_count_ngrams.items(), columns=['ingredient', 'frequency'])

# %%
ingredient_count = ingredient_count.replace(regex=['_'], value=' ')
ingredient_count = ingredient_count.sort_values(by=['frequency'], ascending=False)
ingredient_count
# Out:
#              ingredient  frequency
# 12              minutes    2723346
# 9                  heat    1503923
# 1                   mix    1310617
# 10              mixture    1181963
# 29                 cook    1172832
# ...                 ...        ...
# 9366           pickerel          1
# 9485         chedasharp          1
# 9453              maids          1
# 8750             haddie          1
# 9396  smokey rotisserie          1
#
# [9566 rows x 2 columns]

# %% [markdown]
# - export as excel file for manual revision

# %%
ingredient_count.to_excel('SRM_ingredient_list_unedited.xlsx')

# %% [markdown]
# - save adjusted ingredient list after manual revision as pickle file for the modeling of the SRM

# %%
df_ingredient_list = pd.read_excel('SRM_ingredient_list_final.xlsx')
df_ingredient_list.index = np.arange(1, (len(df_ingredient_list) + 1))

# %%
df_ingredient_list
# Out:
#         ingredient  frequency
# 1            sugar     862777
# 2            water     819858
# 3           butter     680430
# 4            flour     652974
# 5             salt     618946
# ...            ...        ...
# 4567        haddie          1
# 4568  panang curry          1
# 4569       striper          1
# 4570         tonka          1
# 4571   triggerfish          1
#
# [4571 rows x 2 columns]

# %%
len(df_ingredient_list[df_ingredient_list.frequency < 5])
# Out:
# 31

# %%
df_ingredient_list.to_pickle('SRM_ingredient_list.pkl')
